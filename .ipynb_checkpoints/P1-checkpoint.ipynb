# %% [markdown]
# # **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note** If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')
#printing out some stats and plotting
print('This image is:', type(image), 'with dimesions:', image.shape)
plt.imshow(image)  #call as plt.imshow(gray, cmap='gray') to show a grayscaled image
# Out:
# This image is: <class 'numpy.ndarray'> with dimesions: (540, 960, 3)

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image


def draw_lines(img, lines, color=[255, 0, 0], thickness=8):
    # reshape lines to a 2d matrix
    lines = lines.reshape(lines.shape[0], lines.shape[2])
    # create array of slopes
    slopes = (lines[:,3] - lines[:,1]) /(lines[:,2] - lines[:,0])
    # remove junk from lists
    lines = lines[~np.isnan(lines) & ~np.isinf(lines)]
    slopes = slopes[~np.isnan(slopes) & ~np.isinf(slopes)]
    # convert lines into list of points
    lines.shape = (lines.shape[0]//2,2)

    # Right lane
    # move all points with negative slopes into right "lane"
    right_slopes = slopes[slopes < 0]
    right_lines = np.array(list(filter(lambda x: x[0] > (img.shape[1]/2), lines)))
    max_right_x, max_right_y = right_lines.max(axis=0)
    min_right_x, min_right_y = right_lines.min(axis=0)

    # Left lane
    # all positive  slopes go into left "lane"
    left_slopes = slopes[slopes > 0]
    left_lines = np.array(list(filter(lambda x: x[0] < (img.shape[1]/2), lines)))
    max_left_x, max_left_y = left_lines.max(axis=0)
    min_left_x, min_left_y = left_lines.min(axis=0)

    # Curve fitting approach
    # calculate polynomial fit for the points in right lane
    right_curve = np.poly1d(np.polyfit(right_lines[:,1], right_lines[:,0], 2))
    left_curve  = np.poly1d(np.polyfit(left_lines[:,1], left_lines[:,0], 2))

    # shared ceiling on the horizon for both lines
    min_y = min(min_left_y, min_right_y)

    # use new curve function f(y) to calculate x values
    max_right_x = int(right_curve(img.shape[0]))
    min_right_x = int(right_curve(min_right_y))

    min_left_x = int(left_curve(img.shape[0]))

    r1 = (min_right_x, min_y)
    r2 = (max_right_x, img.shape[0])
    print('Right points r1 and r2,', r1, r2)
    cv2.line(img, r1, r2, color, thickness)

    l1 = (max_left_x, min_y)
    l2 = (min_left_x, img.shape[0])
    print('Left points l1 and l2,', l1, l2)
    cv2.line(img, l1, l2, color, thickness)


def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %% [markdown]
# ## Test on Images
#
# Now you should build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
# Out:
# ['.DS_Store',
#  'solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidWhiteRight_output.png',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %% [markdown]
# run your solution on all test_images and make copies into the test_images directory).

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import argparse
import math
import cv2

# %%
def process_image(image):
    if image is None: raise ValueError("no image given to mark_lanes")
    # grayscale the image to make finding gradients clearer
    gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

    # Define a kernel size and apply Gaussian smoothing
    kernel_size = 5
    blur_gray = cv2.GaussianBlur(gray,(kernel_size, kernel_size), 0)

    # Define our parameters for Canny and apply
    low_threshold = 50
    high_threshold = 150
    edges_img = cv2.Canny(np.uint8(blur_gray), low_threshold, high_threshold)


    imshape = image.shape
    vertices = np.array([[(0, imshape[0]),
                          (450, 320),
                          (490, 320),
                          (imshape[1], imshape[0]) ]],
                          dtype=np.int32)

    masked_edges = region_of_interest(edges_img, vertices )


    # Define the Hough transform parameters
    rho             = 2           # distance resolution in pixels of the Hough grid
    theta           = np.pi/180   # angular resolution in radians of the Hough grid
    threshold       = 15       # minimum number of votes (intersections in Hough grid cell)
    min_line_length = 20       # minimum number of pixels making up a line
    max_line_gap    = 20       # maximum gap in pixels between connectable line segments

    line_image = hough_lines(masked_edges, rho, theta, threshold, min_line_length, max_line_gap)

    # Draw the lines on the edge image
    # initial_img * α + img * β + λ
    lines_edges = cv2.addWeighted(image, 0.8, line_image, 1, 0)
    return lines_edges

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'white.mp4'
clip1 = VideoFileClip("solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# Right points r1 and r2, (535, 320) (870, 538)
# Left points l1 and l2, (461, 320) (187, 515)
# [MoviePy] >>>> Building video white.mp4
# [MoviePy] Writing video white.mp4
#   1%|          | 2/222 [00:00<00:11, 19.57it/s]
# Right points r1 and r2, (535, 320) (870, 538)
# Left points l1 and l2, (461, 320) (187, 515)
# Right points r1 and r2, (535, 320) (868, 539)
# Left points l1 and l2, (461, 320) (151, 539)
# Right points r1 and r2, (533, 320) (868, 539)
# Left points l1 and l2, (461, 320) (150, 539)
#   2%|▏         | 4/222 [00:00<00:11, 19.44it/s]
# Right points r1 and r2, (533, 320) (864, 538)
# Left points l1 and l2, (460, 320) (149, 539)
#   3%|▎         | 6/222 [00:00<00:11, 19.57it/s]
# Right points r1 and r2, (533, 320) (870, 538)
# Left points l1 and l2, (461, 320) (150, 536)
# Right points r1 and r2, (537, 320) (870, 539)
# Left points l1 and l2, (461, 320) (351, 395)
# Right points r1 and r2, (538, 320) (871, 538)
# Left points l1 and l2, (461, 320) (339, 403)
# Right points r1 and r2, (538, 320) (872, 538)
# Left points l1 and l2, (460, 320) (214, 491)
#   4%|▍         | 9/222 [00:00<00:10, 20.13it/s]
# Right points r1 and r2, (538, 320) (871, 539)
# Left points l1 and l2, (461, 320) (163, 528)
#   5%|▌         | 12/222 [00:00<00:09, 21.37it/s]
# Right points r1 and r2, (520, 320) (866, 538)
# Left points l1 and l2, (464, 320) (289, 440)
# Right points r1 and r2, (530, 320) (860, 539)
# Left points l1 and l2, (467, 320) (263, 461)
# Right points r1 and r2, (506, 320) (856, 538)
# Left points l1 and l2, (468, 320) (230, 484)
# Right points r1 and r2, (516, 320) (855, 539)
# Left points l1 and l2, (466, 320) (183, 515)
# Right points r1 and r2, (522, 320) (855, 539)
# Left points l1 and l2, (463, 320) (145, 539)
# Right points r1 and r2, (525, 320) (857, 539)
# Left points l1 and l2, (459, 320) (142, 538)
#   8%|▊         | 18/222 [00:00<00:09, 22.23it/s]
# Right points r1 and r2, (546, 320) (859, 539)
# Left points l1 and l2, (456, 320) (138, 538)
# Right points r1 and r2, (542, 320) (860, 539)
# Left points l1 and l2, (456, 320) (136, 539)
# Right points r1 and r2, (555, 320) (858, 538)
# Left points l1 and l2, (458, 320) (350, 392)
#   9%|▉         | 21/222 [00:00<00:08, 23.80it/s]
# Right points r1 and r2, (535, 320) (856, 538)
# Left points l1 and l2, (461, 320) (339, 402)
# Right points r1 and r2, (523, 320) (854, 539)
# Left points l1 and l2, (462, 320) (326, 413)
# Right points r1 and r2, (518, 320) (854, 539)
# Left points l1 and l2, (464, 320) (162, 523)
#  11%|█         | 24/222 [00:01<00:08, 24.28it/s]
# Right points r1 and r2, (518, 320) (854, 539)
# Left points l1 and l2, (465, 320) (289, 439)
# Right points r1 and r2, (520, 320) (854, 538)
# Left points l1 and l2, (464, 320) (264, 456)
# Right points r1 and r2, (523, 320) (854, 538)
# Left points l1 and l2, (462, 320) (232, 479)
# Right points r1 and r2, (525, 320) (855, 539)
# Left points l1 and l2, (463, 320) (186, 510)
# Right points r1 and r2, (525, 320) (854, 538)
# Left points l1 and l2, (458, 320) (141, 538)
# Right points r1 and r2, (525, 320) (855, 538)
# Left points l1 and l2, (462, 320) (142, 539)
#  12%|█▏        | 27/222 [00:01<00:07, 24.45it/s]
# Right points r1 and r2, (525, 320) (856, 539)
# Left points l1 and l2, (463, 320) (144, 539)
# Right points r1 and r2, (525, 320) (856, 539)
# Left points l1 and l2, (463, 320) (362, 390)
#  14%|█▎        | 30/222 [00:01<00:08, 23.09it/s]
# Right points r1 and r2, (527, 320) (856, 539)
# Left points l1 and l2, (462, 320) (352, 395)
# Right points r1 and r2, (531, 320) (857, 539)
# Left points l1 and l2, (460, 320) (341, 402)
# Right points r1 and r2, (531, 320) (858, 539)
# Left points l1 and l2, (460, 320) (328, 412)
# Right points r1 and r2, (533, 320) (858, 538)
# Left points l1 and l2, (460, 320) (171, 519)
#  15%|█▍        | 33/222 [00:01<00:07, 23.81it/s]
# Right points r1 and r2, (531, 320) (858, 539)
# Left points l1 and l2, (461, 320) (292, 436)
# Right points r1 and r2, (527, 320) (856, 539)
# Left points l1 and l2, (461, 320) (269, 455)
# Right points r1 and r2, (523, 320) (844, 538)
# Left points l1 and l2, (462, 320) (235, 478)
#  16%|█▌        | 36/222 [00:01<00:11, 16.12it/s]
# Right points r1 and r2, (529, 320) (855, 539)
# Left points l1 and l2, (463, 320) (191, 509)
#  17%|█▋        | 38/222 [00:01<00:13, 13.95it/s]
# Right points r1 and r2, (528, 320) (853, 539)
# Left points l1 and l2, (464, 320) (146, 538)
# Right points r1 and r2, (535, 320) (855, 539)
# Left points l1 and l2, (462, 320) (145, 539)
#  18%|█▊        | 40/222 [00:02<00:13, 13.32it/s]
# Right points r1 and r2, (535, 320) (855, 538)
# Left points l1 and l2, (462, 320) (142, 539)
#  19%|█▉        | 43/222 [00:02<00:11, 15.63it/s]
# Right points r1 and r2, (537, 320) (855, 538)
# Left points l1 and l2, (460, 320) (142, 539)
# Right points r1 and r2, (539, 320) (855, 538)
# Left points l1 and l2, (459, 320) (354, 393)
# Right points r1 and r2, (538, 320) (853, 538)
# Left points l1 and l2, (459, 320) (343, 401)
# Right points r1 and r2, (538, 320) (855, 538)
# Left points l1 and l2, (459, 320) (329, 409)
#  20%|██        | 45/222 [00:02<00:12, 14.44it/s]
# Right points r1 and r2, (538, 320) (853, 539)
# Left points l1 and l2, (460, 320) (175, 514)
# Right points r1 and r2, (537, 320) (854, 538)
# Left points l1 and l2, (459, 320) (295, 434)
# Right points r1 and r2, (538, 320) (839, 538)
# Left points l1 and l2, (457, 320) (271, 450)
#  22%|██▏       | 49/222 [00:03<00:20,  8.53it/s]
# Right points r1 and r2, (538, 320) (854, 539)
# Left points l1 and l2, (459, 320) (240, 472)
# Right points r1 and r2, (535, 320) (853, 539)
# Left points l1 and l2, (459, 320) (198, 501)
# Right points r1 and r2, (533, 320) (848, 538)
# Left points l1 and l2, (460, 320) (140, 538)
#  24%|██▍       | 53/222 [00:03<00:15, 10.99it/s]
# Right points r1 and r2, (535, 320) (853, 539)
# Left points l1 and l2, (459, 320) (139, 539)
# Right points r1 and r2, (535, 320) (852, 539)
# Left points l1 and l2, (460, 320) (137, 539)
# Right points r1 and r2, (537, 320) (842, 539)
# Left points l1 and l2, (459, 320) (135, 539)
#  25%|██▍       | 55/222 [00:03<00:15, 10.95it/s]
# Right points r1 and r2, (535, 320) (852, 539)
# Left points l1 and l2, (459, 320) (348, 393)
# Right points r1 and r2, (535, 320) (852, 539)
# Left points l1 and l2, (460, 320) (337, 401)
# Right points r1 and r2, (522, 320) (852, 539)
# Left points l1 and l2, (461, 320) (323, 411)
#  27%|██▋       | 59/222 [00:03<00:13, 11.95it/s]
# Right points r1 and r2, (514, 320) (852, 539)
# Left points l1 and l2, (461, 320) (170, 515)
# Right points r1 and r2, (510, 320) (850, 538)
# Left points l1 and l2, (463, 320) (285, 437)
# Right points r1 and r2, (510, 320) (846, 538)
# Left points l1 and l2, (463, 320) (260, 454)
#  28%|██▊       | 62/222 [00:04<00:11, 13.42it/s]
# Right points r1 and r2, (518, 320) (848, 539)
# Left points l1 and l2, (463, 320) (226, 476)
# Right points r1 and r2, (511, 320) (845, 539)
# Left points l1 and l2, (463, 320) (182, 507)
# Right points r1 and r2, (511, 320) (844, 539)
# Left points l1 and l2, (463, 320) (131, 538)
# Right points r1 and r2, (508, 320) (844, 539)
# Left points l1 and l2, (460, 320) (132, 539)
#  30%|███       | 67/222 [00:04<00:09, 15.87it/s]
# Right points r1 and r2, (508, 320) (843, 539)
# Left points l1 and l2, (462, 320) (131, 539)
# Right points r1 and r2, (508, 320) (842, 539)
# Left points l1 and l2, (462, 320) (129, 538)
# Right points r1 and r2, (512, 320) (843, 538)
# Left points l1 and l2, (462, 320) (347, 394)
# Right points r1 and r2, (520, 320) (844, 539)
# Left points l1 and l2, (460, 320) (335, 400)
#  32%|███▏      | 71/222 [00:04<00:08, 17.30it/s]
# Right points r1 and r2, (520, 320) (846, 539)
# Left points l1 and l2, (459, 320) (211, 481)
# Right points r1 and r2, (518, 320) (846, 539)
# Left points l1 and l2, (460, 320) (165, 510)
# Right points r1 and r2, (516, 321) (844, 539)
# Left points l1 and l2, (455, 321) (287, 433)
# Right points r1 and r2, (516, 320) (844, 539)
# Left points l1 and l2, (460, 320) (261, 449)
# Right points r1 and r2, (516, 320) (843, 539)
# Left points l1 and l2, (460, 320) (230, 470)
#  34%|███▍      | 76/222 [00:04<00:08, 18.21it/s]
# Right points r1 and r2, (514, 320) (842, 538)
# Left points l1 and l2, (460, 320) (187, 498)
# Right points r1 and r2, (514, 320) (842, 539)
# Left points l1 and l2, (461, 320) (127, 539)
# Right points r1 and r2, (514, 320) (841, 538)
# Left points l1 and l2, (460, 320) (123, 539)
# Right points r1 and r2, (516, 320) (841, 539)
# Left points l1 and l2, (459, 320) (120, 538)
#  36%|███▋      | 81/222 [00:04<00:07, 19.46it/s]
# Right points r1 and r2, (516, 320) (840, 539)
# Left points l1 and l2, (458, 320) (119, 538)
# Right points r1 and r2, (531, 320) (839, 539)
# Left points l1 and l2, (458, 320) (345, 392)
# Right points r1 and r2, (518, 320) (836, 539)
# Left points l1 and l2, (459, 320) (333, 400)
# Right points r1 and r2, (516, 320) (835, 539)
# Left points l1 and l2, (458, 320) (319, 409)
# Right points r1 and r2, (518, 320) (834, 539)
# Left points l1 and l2, (454, 320) (302, 419)
#  38%|███▊      | 84/222 [00:05<00:07, 19.39it/s]
# Right points r1 and r2, (516, 320) (833, 539)
# Left points l1 and l2, (458, 320) (282, 432)
# Right points r1 and r2, (518, 320) (833, 539)
# Left points l1 and l2, (458, 320) (257, 448)
# Right points r1 and r2, (521, 320) (832, 539)
# Left points l1 and l2, (459, 320) (226, 468)
# Right points r1 and r2, (518, 320) (832, 539)
# Left points l1 and l2, (458, 320) (182, 498)
#  40%|███▉      | 88/222 [00:05<00:07, 17.64it/s]
# Right points r1 and r2, (520, 320) (832, 538)
# Left points l1 and l2, (458, 320) (123, 536)
# Right points r1 and r2, (520, 320) (831, 539)
# Left points l1 and l2, (460, 320) (117, 539)
# Right points r1 and r2, (523, 320) (823, 539)
# Left points l1 and l2, (461, 320) (118, 539)
# Right points r1 and r2, (520, 320) (831, 539)
# Left points l1 and l2, (461, 320) (118, 538)
#  41%|████      | 90/222 [00:05<00:09, 14.50it/s]
# Right points r1 and r2, (524, 320) (830, 539)
# Left points l1 and l2, (460, 320) (344, 393)
# Right points r1 and r2, (520, 320) (829, 539)
# Left points l1 and l2, (462, 320) (334, 401)
# Right points r1 and r2, (522, 320) (830, 538)
# Left points l1 and l2, (463, 320) (320, 411)
#  42%|████▏     | 94/222 [00:06<00:11, 11.13it/s]
# Right points r1 and r2, (523, 320) (828, 539)
# Left points l1 and l2, (463, 320) (168, 510)
# Right points r1 and r2, (525, 320) (829, 538)
# Left points l1 and l2, (463, 320) (286, 433)
# Right points r1 and r2, (533, 320) (830, 539)
# Left points l1 and l2, (461, 320) (261, 449)
#  44%|████▍     | 98/222 [00:06<00:08, 13.85it/s]
# Right points r1 and r2, (535, 320) (831, 539)
# Left points l1 and l2, (462, 320) (231, 469)
# Right points r1 and r2, (538, 320) (832, 539)
# Left points l1 and l2, (461, 320) (190, 495)
# Right points r1 and r2, (538, 320) (831, 539)
# Left points l1 and l2, (461, 320) (132, 532)
# Right points r1 and r2, (540, 320) (832, 539)
# Left points l1 and l2, (461, 320) (116, 538)
# Right points r1 and r2, (546, 320) (833, 538)
# Left points l1 and l2, (460, 320) (116, 539)
#  47%|████▋     | 104/222 [00:06<00:06, 17.23it/s]
# Right points r1 and r2, (544, 320) (832, 539)
# Left points l1 and l2, (456, 320) (116, 538)
# Right points r1 and r2, (537, 320) (832, 538)
# Left points l1 and l2, (464, 320) (350, 392)
# Right points r1 and r2, (533, 320) (832, 539)
# Left points l1 and l2, (465, 320) (340, 401)
# Right points r1 and r2, (529, 320) (833, 539)
# Left points l1 and l2, (466, 320) (212, 479)
# Right points r1 and r2, (533, 320) (835, 539)
# Left points l1 and l2, (464, 320) (172, 510)
#  49%|████▊     | 108/222 [00:06<00:06, 16.82it/s]
# Right points r1 and r2, (538, 320) (836, 539)
# Left points l1 and l2, (464, 320) (293, 432)
# Right points r1 and r2, (538, 320) (823, 538)
# Left points l1 and l2, (464, 320) (268, 448)
# Right points r1 and r2, (540, 320) (838, 539)
# Left points l1 and l2, (463, 320) (238, 468)
# Right points r1 and r2, (542, 320) (838, 539)
# Left points l1 and l2, (463, 320) (197, 496)
#  50%|█████     | 112/222 [00:07<00:07, 14.71it/s]
# Right points r1 and r2, (537, 320) (838, 539)
# Left points l1 and l2, (465, 320) (142, 532)
# Right points r1 and r2, (538, 320) (837, 539)
# Left points l1 and l2, (465, 320) (132, 539)
# Right points r1 and r2, (533, 320) (838, 539)
# Left points l1 and l2, (465, 320) (133, 539)
#  51%|█████▏    | 114/222 [00:07<00:07, 15.34it/s]
# Right points r1 and r2, (533, 320) (840, 539)
# Left points l1 and l2, (465, 320) (133, 539)
# Right points r1 and r2, (540, 320) (841, 539)
# Left points l1 and l2, (464, 320) (353, 392)
# Right points r1 and r2, (557, 320) (843, 538)
# Left points l1 and l2, (463, 320) (343, 398)
# Right points r1 and r2, (557, 320) (844, 538)
# Left points l1 and l2, (464, 320) (226, 475)
#  53%|█████▎    | 118/222 [00:07<00:07, 14.15it/s]
# Right points r1 and r2, (537, 320) (846, 538)
# Left points l1 and l2, (463, 320) (181, 504)
# Right points r1 and r2, (540, 320) (846, 539)
# Left points l1 and l2, (464, 320) (296, 428)
# Right points r1 and r2, (535, 320) (848, 539)
# Left points l1 and l2, (464, 320) (273, 444)
#  55%|█████▍    | 122/222 [00:07<00:06, 14.49it/s]
# Right points r1 and r2, (535, 320) (847, 538)
# Left points l1 and l2, (466, 320) (244, 464)
# Right points r1 and r2, (533, 320) (850, 539)
# Left points l1 and l2, (466, 320) (206, 491)
# Right points r1 and r2, (525, 320) (851, 539)
# Left points l1 and l2, (466, 320) (152, 528)
# Right points r1 and r2, (533, 320) (852, 539)
# Left points l1 and l2, (467, 320) (132, 539)
#  57%|█████▋    | 126/222 [00:08<00:06, 14.17it/s]
# Right points r1 and r2, (527, 320) (852, 538)
# Left points l1 and l2, (464, 320) (130, 539)
# Right points r1 and r2, (535, 320) (854, 539)
# Left points l1 and l2, (466, 320) (130, 538)
# Right points r1 and r2, (533, 320) (856, 539)
# Left points l1 and l2, (466, 320) (356, 392)
#  58%|█████▊    | 128/222 [00:08<00:06, 14.64it/s]
# Right points r1 and r2, (535, 320) (858, 539)
# Left points l1 and l2, (466, 320) (346, 399)
# Right points r1 and r2, (538, 320) (858, 538)
# Left points l1 and l2, (467, 320) (334, 408)
# Right points r1 and r2, (537, 320) (859, 538)
# Left points l1 and l2, (467, 320) (191, 506)
# Right points r1 and r2, (535, 320) (858, 539)
# Left points l1 and l2, (467, 320) (302, 430)
#  59%|█████▉    | 132/222 [00:08<00:06, 14.04it/s]
# Right points r1 and r2, (531, 320) (859, 538)
# Left points l1 and l2, (468, 320) (280, 447)
# Right points r1 and r2, (535, 320) (858, 539)
# Left points l1 and l2, (467, 320) (252, 467)
# Right points r1 and r2, (533, 320) (859, 539)
# Left points l1 and l2, (468, 320) (215, 493)
#  60%|██████    | 134/222 [00:08<00:06, 13.31it/s]
# Right points r1 and r2, (538, 320) (860, 539)
# Left points l1 and l2, (466, 320) (163, 527)
# Right points r1 and r2, (544, 320) (860, 539)
# Left points l1 and l2, (465, 320) (143, 539)
# Right points r1 and r2, (550, 320) (863, 539)
#  61%|██████▏   | 136/222 [00:08<00:07, 12.19it/s]
# Left points l1 and l2, (462, 320) (141, 539)
# Right points r1 and r2, (552, 320) (864, 539)
# Left points l1 and l2, (461, 320) (141, 539)
#  63%|██████▎   | 140/222 [00:09<00:06, 11.89it/s]
# Right points r1 and r2, (552, 320) (865, 539)
# Left points l1 and l2, (462, 320) (360, 389)
# Right points r1 and r2, (546, 320) (863, 539)
# Left points l1 and l2, (465, 320) (350, 397)
# Right points r1 and r2, (540, 320) (861, 539)
# Left points l1 and l2, (465, 320) (339, 407)
#  64%|██████▍   | 142/222 [00:09<00:06, 12.66it/s]
# Right points r1 and r2, (540, 320) (861, 538)
# Left points l1 and l2, (467, 320) (199, 505)
# Right points r1 and r2, (537, 320) (859, 539)
# Left points l1 and l2, (468, 320) (307, 430)
# Right points r1 and r2, (533, 320) (859, 539)
# Left points l1 and l2, (468, 320) (286, 445)
#  66%|██████▌   | 146/222 [00:09<00:05, 13.01it/s]
# Right points r1 and r2, (537, 320) (859, 539)
# Left points l1 and l2, (468, 320) (259, 465)
# Right points r1 and r2, (540, 320) (859, 539)
# Left points l1 and l2, (467, 320) (224, 489)
# Right points r1 and r2, (552, 320) (863, 539)
# Left points l1 and l2, (467, 320) (175, 524)
#  67%|██████▋   | 148/222 [00:09<00:06, 10.91it/s]
# Right points r1 and r2, (552, 320) (865, 538)
# Left points l1 and l2, (465, 320) (152, 539)
# Right points r1 and r2, (561, 323) (868, 538)
# Left points l1 and l2, (457, 323) (152, 539)
#  68%|██████▊   | 150/222 [00:10<00:06, 10.79it/s]
# Right points r1 and r2, (557, 320) (861, 538)
# Left points l1 and l2, (465, 320) (151, 539)
# Right points r1 and r2, (555, 320) (872, 538)
# Left points l1 and l2, (465, 320) (363, 392)
# Right points r1 and r2, (553, 320) (872, 539)
# Left points l1 and l2, (465, 320) (353, 399)
#  69%|██████▉   | 154/222 [00:10<00:05, 12.46it/s]
# Right points r1 and r2, (553, 320) (870, 539)
# Left points l1 and l2, (467, 320) (341, 408)
# Right points r1 and r2, (553, 320) (868, 539)
# Left points l1 and l2, (467, 320) (328, 418)
# Right points r1 and r2, (553, 320) (869, 539)
# Left points l1 and l2, (466, 320) (314, 429)
# Right points r1 and r2, (563, 320) (870, 539)
# Left points l1 and l2, (465, 320) (290, 445)
# Right points r1 and r2, (565, 320) (866, 539)
# Left points l1 and l2, (464, 320) (263, 461)
# Right points r1 and r2, (567, 320) (871, 539)
# Left points l1 and l2, (465, 320) (227, 489)
#  72%|███████▏  | 159/222 [00:10<00:05, 11.82it/s]
# Right points r1 and r2, (565, 320) (874, 538)
# Left points l1 and l2, (465, 320) (178, 525)
# Right points r1 and r2, (559, 320) (877, 539)
# Left points l1 and l2, (465, 320) (156, 539)
# Right points r1 and r2, (565, 320) (880, 539)
#  73%|███████▎  | 161/222 [00:11<00:05, 10.33it/s]
# Left points l1 and l2, (466, 320) (158, 539)
# Right points r1 and r2, (567, 320) (882, 539)
# Left points l1 and l2, (466, 320) (159, 539)
#  73%|███████▎  | 163/222 [00:11<00:05,  9.90it/s]
# Right points r1 and r2, (571, 320) (883, 539)
# Left points l1 and l2, (468, 320) (370, 390)
# Right points r1 and r2, (580, 320) (885, 539)
# Left points l1 and l2, (468, 320) (360, 397)
# Right points r1 and r2, (550, 320) (886, 538)
# Left points l1 and l2, (469, 320) (255, 473)
# Right points r1 and r2, (550, 320) (887, 539)
# Left points l1 and l2, (466, 320) (217, 502)
#  76%|███████▌  | 168/222 [00:11<00:04, 12.46it/s]
# Right points r1 and r2, (542, 320) (886, 538)
# Left points l1 and l2, (464, 320) (168, 536)
# Right points r1 and r2, (538, 320) (886, 539)
# Left points l1 and l2, (471, 320) (300, 445)
# Right points r1 and r2, (538, 320) (886, 538)
# Left points l1 and l2, (470, 320) (275, 462)
#  77%|███████▋  | 170/222 [00:11<00:04, 11.38it/s]
# Right points r1 and r2, (538, 320) (885, 539)
# Left points l1 and l2, (469, 320) (242, 488)
# Right points r1 and r2, (539, 320) (885, 539)
# Left points l1 and l2, (469, 320) (196, 523)
# Right points r1 and r2, (538, 320) (884, 538)
# Left points l1 and l2, (469, 320) (175, 539)
#  79%|███████▉  | 175/222 [00:11<00:03, 14.54it/s]
# Right points r1 and r2, (541, 320) (884, 539)
# Left points l1 and l2, (467, 320) (176, 539)
# Right points r1 and r2, (550, 320) (884, 538)
# Left points l1 and l2, (468, 320) (175, 539)
# Right points r1 and r2, (548, 325) (885, 538)
# Left points l1 and l2, (456, 325) (373, 391)
# Right points r1 and r2, (548, 320) (886, 539)
# Left points l1 and l2, (469, 320) (364, 398)
# Right points r1 and r2, (550, 320) (885, 539)
# Left points l1 and l2, (469, 320) (353, 406)
#  82%|████████▏ | 181/222 [00:12<00:02, 18.30it/s]
# Right points r1 and r2, (557, 320) (885, 538)
# Left points l1 and l2, (471, 320) (340, 417)
# Right points r1 and r2, (552, 320) (885, 539)
# Left points l1 and l2, (470, 320) (180, 536)
# Right points r1 and r2, (553, 320) (886, 539)
# Left points l1 and l2, (470, 320) (307, 441)
# Right points r1 and r2, (563, 320) (888, 538)
# Left points l1 and l2, (468, 320) (283, 461)
# Right points r1 and r2, (563, 320) (888, 538)
# Left points l1 and l2, (468, 320) (250, 485)
#  83%|████████▎ | 184/222 [00:12<00:02, 18.02it/s]
# Right points r1 and r2, (565, 320) (890, 539)
# Left points l1 and l2, (464, 320) (207, 520)
# Right points r1 and r2, (568, 320) (890, 539)
# Left points l1 and l2, (465, 320) (181, 539)
# Right points r1 and r2, (569, 320) (889, 539)
# Left points l1 and l2, (468, 320) (181, 539)
# Right points r1 and r2, (572, 320) (889, 538)
# Left points l1 and l2, (467, 320) (179, 538)
#  85%|████████▌ | 189/222 [00:12<00:01, 18.65it/s]
# Right points r1 and r2, (568, 320) (887, 539)
# Left points l1 and l2, (468, 320) (373, 389)
# Right points r1 and r2, (561, 320) (886, 539)
# Left points l1 and l2, (467, 320) (363, 396)
# Right points r1 and r2, (568, 320) (891, 539)
# Left points l1 and l2, (463, 320) (269, 469)
# Right points r1 and r2, (585, 320) (897, 539)
# Left points l1 and l2, (463, 320) (234, 492)
# Right points r1 and r2, (602, 320) (903, 539)
# Left points l1 and l2, (458, 320) (182, 533)
#  88%|████████▊ | 195/222 [00:12<00:01, 20.54it/s]
# Right points r1 and r2, (600, 320) (905, 539)
# Left points l1 and l2, (463, 320) (306, 438)
# Right points r1 and r2, (585, 320) (904, 538)
# Left points l1 and l2, (463, 320) (282, 458)
# Right points r1 and r2, (557, 320) (878, 539)
# Left points l1 and l2, (471, 320) (252, 486)
# Right points r1 and r2, (482, 320) (892, 539)
# Left points l1 and l2, (476, 320) (205, 520)
# Right points r1 and r2, (565, 320) (890, 539)
# Left points l1 and l2, (471, 320) (177, 538)
#  89%|████████▉ | 198/222 [00:13<00:01, 21.05it/s]
# Right points r1 and r2, (483, 320) (886, 538)
# Left points l1 and l2, (475, 320) (178, 538)
# Right points r1 and r2, (539, 320) (889, 538)
# Left points l1 and l2, (467, 320) (178, 539)
# Right points r1 and r2, (552, 320) (890, 539)
# Left points l1 and l2, (469, 320) (371, 390)
# Right points r1 and r2, (550, 320) (891, 539)
# Left points l1 and l2, (466, 320) (363, 397)
# Right points r1 and r2, (542, 320) (890, 539)
# Left points l1 and l2, (466, 320) (268, 470)
#  92%|█████████▏| 204/222 [00:13<00:00, 22.40it/s]
# Right points r1 and r2, (553, 320) (893, 538)
# Left points l1 and l2, (467, 320) (232, 498)
# Right points r1 and r2, (559, 320) (891, 535)
# Left points l1 and l2, (464, 320) (191, 533)
# Right points r1 and r2, (563, 320) (895, 538)
# Left points l1 and l2, (466, 320) (305, 441)
# Right points r1 and r2, (567, 320) (899, 538)
# Left points l1 and l2, (467, 320) (281, 460)
# Right points r1 and r2, (576, 320) (900, 538)
# Left points l1 and l2, (465, 320) (249, 484)
#  95%|█████████▍| 210/222 [00:13<00:00, 22.26it/s]
# Right points r1 and r2, (573, 320) (901, 538)
# Left points l1 and l2, (466, 320) (204, 519)
# Right points r1 and r2, (582, 320) (903, 539)
# Left points l1 and l2, (462, 320) (176, 539)
# Right points r1 and r2, (580, 320) (903, 539)
# Left points l1 and l2, (464, 320) (176, 539)
# Right points r1 and r2, (576, 320) (907, 538)
# Left points l1 and l2, (466, 320) (178, 538)
# Right points r1 and r2, (567, 320) (906, 539)
# Left points l1 and l2, (464, 320) (373, 388)
#  96%|█████████▌| 213/222 [00:13<00:00, 23.00it/s]
# Right points r1 and r2, (568, 320) (906, 539)
# Left points l1 and l2, (468, 320) (363, 395)
# Right points r1 and r2, (553, 320) (905, 539)
# Left points l1 and l2, (466, 320) (354, 404)
# Right points r1 and r2, (555, 320) (903, 539)
# Left points l1 and l2, (469, 320) (233, 496)
# Right points r1 and r2, (538, 320) (900, 539)
# Left points l1 and l2, (470, 320) (182, 536)
# Right points r1 and r2, (538, 320) (899, 539)
# Left points l1 and l2, (469, 320) (305, 442)
# Right points r1 and r2, (485, 320) (885, 538)
# Left points l1 and l2, (469, 320) (280, 462)
# 100%|█████████▉| 221/222 [00:14<00:00, 15.72it/s]
# Right points r1 and r2, (531, 320) (897, 539)
# Left points l1 and l2, (471, 320) (250, 488)
# Right points r1 and r2, (523, 320) (897, 538)
# Left points l1 and l2, (469, 320) (203, 522)
# Right points r1 and r2, (538, 321) (897, 538)
# Left points l1 and l2, (468, 321) (178, 539)
# Right points r1 and r2, (543, 320) (896, 539)
# Left points l1 and l2, (469, 320) (182, 539)
# Right points r1 and r2, (538, 320) (897, 538)
# Left points l1 and l2, (467, 320) (175, 539)
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: white.mp4
#
# CPU times: user 8.47 s, sys: 960 ms, total: 9.43 s
# Wall time: 15 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="white.mp4">
# </video>

# %% [markdown]
# **At this point, if you were successful you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform.  Modify your draw_lines function accordingly and try re-running your pipeline.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'yellow.mp4'
clip2 = VideoFileClip('solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# Right points r1 and r2, (538, 320) (775, 497)
# Left points l1 and l2, (461, 320) (105, 538)
# [MoviePy] >>>> Building video yellow.mp4
# [MoviePy] Writing video yellow.mp4
#   0%|          | 3/682 [00:00<00:27, 24.98it/s]
# Right points r1 and r2, (538, 320) (775, 497)
# Left points l1 and l2, (461, 320) (105, 538)
# Right points r1 and r2, (537, 320) (831, 535)
# Left points l1 and l2, (461, 320) (105, 538)
# Right points r1 and r2, (539, 320) (839, 539)
# Left points l1 and l2, (456, 320) (106, 538)
# Right points r1 and r2, (541, 320) (840, 539)
# Left points l1 and l2, (461, 320) (111, 539)
# Right points r1 and r2, (543, 320) (842, 538)
# Left points l1 and l2, (459, 320) (115, 538)
#   1%|          | 8/682 [00:00<00:28, 23.80it/s]
# Right points r1 and r2, (546, 320) (618, 394)
# Left points l1 and l2, (459, 320) (118, 539)
# Right points r1 and r2, (548, 326) (630, 400)
# Left points l1 and l2, (457, 326) (120, 539)
# Right points r1 and r2, (550, 320) (742, 471)
# Left points l1 and l2, (459, 320) (120, 538)
# Right points r1 and r2, (553, 320) (785, 496)
# Left points l1 and l2, (457, 320) (120, 538)
# Right points r1 and r2, (555, 320) (843, 534)
# Left points l1 and l2, (460, 320) (120, 538)
# Right points r1 and r2, (546, 320) (690, 442)
# Left points l1 and l2, (459, 320) (123, 539)
#   2%|▏         | 14/682 [00:00<00:27, 24.11it/s]
# Right points r1 and r2, (548, 320) (729, 460)
# Left points l1 and l2, (459, 320) (124, 539)
# Right points r1 and r2, (574, 320) (767, 484)
# Left points l1 and l2, (455, 320) (126, 539)
# Right points r1 and r2, (553, 320) (819, 516)
# Left points l1 and l2, (454, 320) (127, 539)
# Right points r1 and r2, (544, 320) (859, 538)
# Left points l1 and l2, (458, 320) (129, 538)
#   2%|▏         | 17/682 [00:00<00:30, 21.76it/s]
# Right points r1 and r2, (542, 320) (861, 538)
# Left points l1 and l2, (457, 320) (131, 539)
# Right points r1 and r2, (544, 320) (861, 538)
# Left points l1 and l2, (457, 320) (132, 539)
# Right points r1 and r2, (544, 320) (619, 390)
# Left points l1 and l2, (453, 320) (136, 539)
# Right points r1 and r2, (546, 320) (707, 442)
# Left points l1 and l2, (452, 320) (136, 539)
#   3%|▎         | 20/682 [00:00<00:28, 23.21it/s]
# Right points r1 and r2, (547, 320) (736, 460)
# Left points l1 and l2, (454, 320) (136, 539)
#   3%|▎         | 23/682 [00:00<00:28, 23.47it/s]
# Right points r1 and r2, (550, 320) (775, 484)
# Left points l1 and l2, (455, 320) (134, 539)
# Right points r1 and r2, (555, 321) (826, 515)
# Left points l1 and l2, (453, 321) (134, 538)
# Right points r1 and r2, (629, 320) (697, 436)
# Left points l1 and l2, (454, 320) (133, 538)
# Right points r1 and r2, (642, 324) (725, 453)
# Left points l1 and l2, (445, 324) (132, 539)
# Right points r1 and r2, (656, 320) (759, 475)
# Left points l1 and l2, (454, 320) (134, 538)
#   4%|▍         | 26/682 [00:01<00:26, 24.37it/s]
# Right points r1 and r2, (566, 320) (806, 503)
# Left points l1 and l2, (456, 320) (137, 539)
#   4%|▍         | 29/682 [00:01<00:27, 23.51it/s]
# Right points r1 and r2, (571, 320) (871, 538)
# Left points l1 and l2, (454, 320) (139, 538)
# Right points r1 and r2, (575, 320) (872, 539)
# Left points l1 and l2, (454, 320) (138, 538)
# Right points r1 and r2, (580, 321) (875, 539)
# Left points l1 and l2, (453, 321) (139, 539)
# Right points r1 and r2, (586, 320) (877, 538)
# Left points l1 and l2, (454, 320) (151, 539)
#   5%|▍         | 32/682 [00:01<00:25, 25.06it/s]
# Right points r1 and r2, (593, 320) (627, 390)
# Left points l1 and l2, (454, 320) (141, 539)
# Right points r1 and r2, (599, 320) (639, 398)
# Left points l1 and l2, (454, 320) (143, 539)
#   5%|▌         | 35/682 [00:01<00:24, 26.14it/s]
# Right points r1 and r2, (607, 320) (654, 405)
# Left points l1 and l2, (453, 320) (143, 539)
# Right points r1 and r2, (617, 322) (811, 498)
# Left points l1 and l2, (451, 322) (144, 539)
# Right points r1 and r2, (626, 320) (878, 535)
# Left points l1 and l2, (452, 320) (146, 539)
# Right points r1 and r2, (638, 320) (714, 441)
# Left points l1 and l2, (451, 320) (146, 539)
#   6%|▌         | 38/682 [00:01<00:24, 26.59it/s]
# Right points r1 and r2, (652, 320) (746, 460)
# Left points l1 and l2, (452, 320) (146, 539)
# Right points r1 and r2, (668, 324) (786, 481)
# Left points l1 and l2, (444, 324) (148, 539)
#   6%|▌         | 41/682 [00:01<00:23, 27.14it/s]
# Right points r1 and r2, (689, 320) (841, 515)
# Left points l1 and l2, (451, 320) (147, 539)
# Right points r1 and r2, (714, 320) (884, 539)
# Left points l1 and l2, (450, 320) (144, 539)
# Right points r1 and r2, (577, 320) (884, 538)
# Left points l1 and l2, (449, 320) (145, 539)
# Right points r1 and r2, (581, 320) (883, 539)
# Left points l1 and l2, (450, 320) (145, 539)
#   6%|▋         | 44/682 [00:01<00:23, 27.22it/s]
# Right points r1 and r2, (587, 320) (884, 538)
# Left points l1 and l2, (450, 320) (143, 539)
# Right points r1 and r2, (594, 320) (632, 393)
# Left points l1 and l2, (449, 320) (143, 539)
#   7%|▋         | 47/682 [00:01<00:26, 24.33it/s]
# Right points r1 and r2, (601, 321) (645, 402)
# Left points l1 and l2, (451, 321) (145, 539)
# Right points r1 and r2, (553, 320) (784, 482)
# Left points l1 and l2, (451, 320) (164, 538)
# Right points r1 and r2, (553, 320) (838, 513)
# Left points l1 and l2, (452, 320) (145, 539)
# Right points r1 and r2, (629, 322) (699, 435)
# Left points l1 and l2, (449, 322) (145, 539)
#   7%|▋         | 50/682 [00:02<00:27, 23.09it/s]
# Right points r1 and r2, (639, 320) (727, 451)
# Left points l1 and l2, (452, 320) (146, 539)
# Right points r1 and r2, (654, 323) (761, 471)
# Left points l1 and l2, (447, 323) (145, 539)
# Right points r1 and r2, (672, 325) (809, 499)
# Left points l1 and l2, (446, 325) (144, 539)
# Right points r1 and r2, (567, 324) (873, 537)
# Left points l1 and l2, (448, 324) (144, 539)
# Right points r1 and r2, (554, 322) (877, 539)
# Left points l1 and l2, (446, 322) (143, 539)
#   8%|▊         | 56/682 [00:02<00:29, 21.15it/s]
# Right points r1 and r2, (557, 324) (877, 538)
# Left points l1 and l2, (449, 324) (143, 539)
# Right points r1 and r2, (544, 320) (876, 539)
# Left points l1 and l2, (453, 320) (142, 538)
# Right points r1 and r2, (544, 321) (622, 390)
# Left points l1 and l2, (452, 321) (141, 539)
# Right points r1 and r2, (544, 322) (633, 397)
# Left points l1 and l2, (448, 322) (141, 539)
# Right points r1 and r2, (544, 320) (751, 466)
# Left points l1 and l2, (453, 320) (142, 539)
#   9%|▊         | 59/682 [00:02<00:29, 21.16it/s]
# Right points r1 and r2, (547, 322) (793, 491)
# Left points l1 and l2, (451, 322) (141, 539)
# Right points r1 and r2, (550, 320) (850, 526)
# Left points l1 and l2, (452, 320) (140, 538)
# Right points r1 and r2, (540, 321) (705, 441)
# Left points l1 and l2, (453, 321) (140, 539)
#   9%|▉         | 62/682 [00:02<00:29, 21.13it/s]
# Right points r1 and r2, (542, 320) (733, 458)
# Left points l1 and l2, (452, 320) (137, 538)
# Right points r1 and r2, (660, 320) (771, 480)
# Left points l1 and l2, (452, 320) (136, 539)
#  10%|▉         | 65/682 [00:02<00:29, 20.63it/s]
# Right points r1 and r2, (546, 320) (821, 510)
# Left points l1 and l2, (452, 320) (135, 539)
# Right points r1 and r2, (549, 320) (864, 538)
# Left points l1 and l2, (453, 320) (136, 539)
# Right points r1 and r2, (538, 320) (870, 539)
# Left points l1 and l2, (454, 320) (136, 539)
# Right points r1 and r2, (538, 320) (869, 539)
# Left points l1 and l2, (455, 320) (137, 539)
#  10%|▉         | 68/682 [00:03<00:32, 18.75it/s]
# Right points r1 and r2, (538, 320) (869, 538)
# Left points l1 and l2, (455, 320) (139, 539)
# Right points r1 and r2, (540, 322) (624, 394)
# Left points l1 and l2, (449, 322) (138, 539)
# Right points r1 and r2, (542, 320) (728, 455)
# Left points l1 and l2, (456, 320) (138, 539)
# Right points r1 and r2, (544, 320) (762, 476)
# Left points l1 and l2, (456, 320) (138, 538)
#  10%|█         | 71/682 [00:03<00:31, 19.50it/s]
# Right points r1 and r2, (547, 320) (811, 505)
# Left points l1 and l2, (456, 320) (137, 538)
#  11%|█         | 74/682 [00:03<00:30, 19.85it/s]
# Right points r1 and r2, (537, 322) (875, 539)
# Left points l1 and l2, (450, 322) (137, 539)
# Right points r1 and r2, (552, 322) (710, 448)
# Left points l1 and l2, (455, 322) (138, 539)
# Right points r1 and r2, (531, 320) (742, 467)
# Left points l1 and l2, (455, 320) (138, 539)
# Right points r1 and r2, (533, 320) (784, 493)
# Left points l1 and l2, (457, 320) (139, 538)
#  12%|█▏        | 80/682 [00:03<00:29, 20.52it/s]
# Right points r1 and r2, (532, 320) (840, 527)
# Left points l1 and l2, (457, 320) (139, 539)
# Right points r1 and r2, (533, 320) (861, 539)
# Left points l1 and l2, (457, 320) (138, 538)
# Right points r1 and r2, (534, 320) (860, 539)
# Left points l1 and l2, (456, 320) (137, 538)
# Right points r1 and r2, (536, 320) (860, 538)
# Left points l1 and l2, (455, 320) (137, 539)
# Right points r1 and r2, (538, 321) (610, 390)
# Left points l1 and l2, (454, 321) (137, 539)
#  12%|█▏        | 85/682 [00:03<00:32, 18.25it/s]
# Right points r1 and r2, (540, 320) (625, 396)
# Left points l1 and l2, (456, 320) (135, 538)
# Right points r1 and r2, (542, 321) (726, 457)
# Left points l1 and l2, (455, 321) (135, 539)
# Right points r1 and r2, (545, 320) (761, 475)
# Left points l1 and l2, (456, 320) (134, 539)
# Right points r1 and r2, (537, 320) (810, 509)
# Left points l1 and l2, (456, 320) (134, 539)
#  13%|█▎        | 89/682 [00:04<00:33, 17.82it/s]
# Right points r1 and r2, (538, 320) (690, 437)
# Left points l1 and l2, (450, 320) (133, 539)
# Right points r1 and r2, (540, 320) (717, 452)
# Left points l1 and l2, (455, 320) (131, 539)
# Right points r1 and r2, (543, 320) (751, 474)
# Left points l1 and l2, (456, 320) (129, 539)
# Right points r1 and r2, (533, 320) (796, 501)
# Left points l1 and l2, (456, 320) (128, 539)
#  14%|█▍        | 94/682 [00:04<00:31, 18.80it/s]
# Right points r1 and r2, (531, 320) (859, 539)
# Left points l1 and l2, (456, 320) (129, 539)
# Right points r1 and r2, (534, 320) (857, 538)
# Left points l1 and l2, (457, 320) (130, 539)
# Right points r1 and r2, (523, 320) (855, 539)
# Left points l1 and l2, (458, 320) (133, 539)
# Right points r1 and r2, (521, 320) (854, 538)
# Left points l1 and l2, (461, 320) (134, 539)
# Right points r1 and r2, (522, 320) (612, 392)
# Left points l1 and l2, (462, 320) (136, 539)
#  15%|█▍        | 99/682 [00:04<00:30, 18.92it/s]
# Right points r1 and r2, (514, 320) (622, 399)
# Left points l1 and l2, (462, 320) (136, 539)
# Right points r1 and r2, (523, 320) (731, 463)
# Left points l1 and l2, (461, 320) (137, 539)
# Right points r1 and r2, (525, 320) (767, 486)
# Left points l1 and l2, (461, 320) (137, 539)
# Right points r1 and r2, (526, 321) (820, 519)
# Left points l1 and l2, (459, 321) (137, 539)
# Right points r1 and r2, (527, 320) (683, 436)
# Left points l1 and l2, (460, 320) (137, 538)
#  15%|█▌        | 104/682 [00:04<00:29, 19.67it/s]
# Right points r1 and r2, (529, 320) (709, 451)
# Left points l1 and l2, (460, 320) (138, 538)
# Right points r1 and r2, (530, 320) (741, 470)
# Left points l1 and l2, (460, 320) (135, 538)
# Right points r1 and r2, (532, 320) (782, 496)
# Left points l1 and l2, (460, 320) (135, 539)
# Right points r1 and r2, (533, 329) (839, 531)
# Left points l1 and l2, (442, 329) (135, 539)
# Right points r1 and r2, (535, 320) (854, 539)
# Left points l1 and l2, (460, 320) (135, 538)
#  16%|█▌        | 107/682 [00:05<00:28, 19.89it/s]
# Right points r1 and r2, (536, 320) (856, 539)
# Left points l1 and l2, (459, 320) (132, 539)
# Right points r1 and r2, (539, 320) (855, 539)
# Left points l1 and l2, (460, 320) (133, 539)
# Right points r1 and r2, (540, 321) (616, 392)
# Left points l1 and l2, (459, 321) (133, 539)
# Right points r1 and r2, (523, 320) (627, 399)
# Left points l1 and l2, (461, 320) (132, 539)
# Right points r1 and r2, (525, 320) (743, 466)
# Left points l1 and l2, (461, 320) (134, 539)
#  17%|█▋        | 113/682 [00:05<00:27, 20.35it/s]
# Right points r1 and r2, (526, 320) (783, 492)
# Left points l1 and l2, (463, 320) (134, 539)
# Right points r1 and r2, (527, 326) (839, 525)
# Left points l1 and l2, (453, 326) (153, 539)
# Right points r1 and r2, (528, 320) (695, 441)
# Left points l1 and l2, (462, 320) (136, 538)
# Right points r1 and r2, (530, 320) (722, 458)
# Left points l1 and l2, (463, 320) (137, 539)
#  17%|█▋        | 116/682 [00:05<00:28, 20.06it/s]
# Right points r1 and r2, (532, 320) (757, 479)
# Left points l1 and l2, (463, 320) (137, 538)
# Right points r1 and r2, (534, 320) (805, 508)
# Left points l1 and l2, (464, 320) (137, 538)
# Right points r1 and r2, (535, 320) (860, 539)
# Left points l1 and l2, (463, 320) (137, 539)
# Right points r1 and r2, (537, 323) (857, 539)
# Left points l1 and l2, (459, 323) (136, 539)
#  18%|█▊        | 122/682 [00:05<00:26, 20.90it/s]
# Right points r1 and r2, (539, 320) (860, 539)
# Left points l1 and l2, (464, 320) (137, 538)
# Right points r1 and r2, (541, 320) (860, 539)
# Left points l1 and l2, (464, 320) (137, 539)
# Right points r1 and r2, (544, 320) (626, 397)
# Left points l1 and l2, (464, 320) (138, 539)
# Right points r1 and r2, (536, 320) (730, 459)
# Left points l1 and l2, (464, 320) (139, 539)
# Right points r1 and r2, (538, 320) (766, 480)
# Left points l1 and l2, (464, 320) (145, 539)
#  18%|█▊        | 125/682 [00:05<00:25, 21.55it/s]
# Right points r1 and r2, (531, 320) (815, 510)
# Left points l1 and l2, (464, 320) (140, 539)
# Right points r1 and r2, (530, 320) (691, 438)
# Left points l1 and l2, (465, 320) (141, 539)
# Right points r1 and r2, (531, 320) (718, 453)
# Left points l1 and l2, (466, 320) (142, 539)
# Right points r1 and r2, (533, 320) (751, 474)
# Left points l1 and l2, (465, 320) (143, 539)
# Right points r1 and r2, (535, 320) (795, 502)
# Left points l1 and l2, (463, 320) (143, 538)
#  19%|█▉        | 131/682 [00:06<00:25, 21.21it/s]
# Right points r1 and r2, (536, 320) (856, 538)
# Left points l1 and l2, (466, 320) (144, 539)
# Right points r1 and r2, (537, 320) (859, 539)
# Left points l1 and l2, (467, 320) (142, 539)
# Right points r1 and r2, (539, 320) (860, 538)
# Left points l1 and l2, (467, 320) (143, 539)
# Right points r1 and r2, (527, 320) (860, 539)
# Left points l1 and l2, (466, 320) (143, 539)
# Right points r1 and r2, (527, 320) (620, 394)
# Left points l1 and l2, (467, 320) (142, 539)
#  20%|██        | 137/682 [00:06<00:25, 21.65it/s]
# Right points r1 and r2, (530, 320) (631, 400)
# Left points l1 and l2, (467, 320) (142, 539)
# Right points r1 and r2, (529, 320) (644, 409)
# Left points l1 and l2, (467, 320) (142, 539)
# Right points r1 and r2, (531, 320) (788, 493)
# Left points l1 and l2, (467, 320) (143, 539)
# Right points r1 and r2, (531, 320) (845, 530)
# Left points l1 and l2, (468, 320) (142, 539)
# Right points r1 and r2, (532, 320) (701, 444)
# Left points l1 and l2, (468, 320) (144, 538)
#  21%|██        | 140/682 [00:06<00:25, 21.39it/s]
# Right points r1 and r2, (533, 320) (730, 461)
# Left points l1 and l2, (467, 320) (144, 539)
# Right points r1 and r2, (523, 320) (767, 483)
# Left points l1 and l2, (467, 320) (143, 539)
# Right points r1 and r2, (523, 320) (816, 514)
# Left points l1 and l2, (464, 320) (142, 539)
# Right points r1 and r2, (523, 320) (862, 539)
# Left points l1 and l2, (467, 320) (142, 539)
# Right points r1 and r2, (523, 320) (860, 538)
# Left points l1 and l2, (467, 320) (143, 539)
#  21%|██▏       | 146/682 [00:06<00:24, 22.32it/s]
# Right points r1 and r2, (525, 320) (862, 538)
# Left points l1 and l2, (467, 320) (142, 539)
# Right points r1 and r2, (525, 320) (615, 391)
# Left points l1 and l2, (466, 320) (143, 538)
# Right points r1 and r2, (526, 320) (625, 397)
# Left points l1 and l2, (467, 320) (144, 538)
# Right points r1 and r2, (514, 320) (730, 459)
# Left points l1 and l2, (466, 320) (142, 539)
# Right points r1 and r2, (528, 320) (766, 479)
# Left points l1 and l2, (467, 320) (142, 538)
#  22%|██▏       | 149/682 [00:06<00:23, 22.43it/s]
# Right points r1 and r2, (530, 321) (815, 509)
# Left points l1 and l2, (466, 321) (142, 539)
# Right points r1 and r2, (508, 320) (690, 436)
# Left points l1 and l2, (466, 320) (142, 539)
# Right points r1 and r2, (522, 320) (716, 451)
# Left points l1 and l2, (467, 320) (141, 538)
#  22%|██▏       | 152/682 [00:07<00:30, 17.40it/s]
# Right points r1 and r2, (510, 320) (749, 471)
# Left points l1 and l2, (467, 320) (142, 538)
# Right points r1 and r2, (495, 320) (792, 498)
# Left points l1 and l2, (467, 320) (142, 538)
# Right points r1 and r2, (506, 320) (852, 533)
# Left points l1 and l2, (467, 320) (143, 539)
# Right points r1 and r2, (506, 320) (865, 538)
# Left points l1 and l2, (467, 320) (144, 538)
#  23%|██▎       | 158/682 [00:07<00:26, 19.54it/s]
# Right points r1 and r2, (506, 321) (865, 539)
# Left points l1 and l2, (468, 321) (146, 538)
# Right points r1 and r2, (494, 320) (864, 539)
# Left points l1 and l2, (468, 320) (147, 539)
# Right points r1 and r2, (493, 320) (625, 396)
# Left points l1 and l2, (474, 320) (149, 539)
# Right points r1 and r2, (496, 320) (637, 404)
# Left points l1 and l2, (479, 320) (150, 539)
# Right points r1 and r2, (491, 320) (651, 412)
# Left points l1 and l2, (472, 320) (151, 538)
#  24%|██▎       | 161/682 [00:07<00:25, 20.39it/s]
# Right points r1 and r2, (485, 320) (800, 496)
# Left points l1 and l2, (474, 320) (158, 538)
# Right points r1 and r2, (489, 320) (864, 536)
# Left points l1 and l2, (473, 320) (154, 538)
# Right points r1 and r2, (490, 321) (710, 447)
# Left points l1 and l2, (474, 321) (155, 539)
# Right points r1 and r2, (494, 320) (742, 464)
# Left points l1 and l2, (473, 320) (154, 539)
# Right points r1 and r2, (492, 320) (780, 486)
# Left points l1 and l2, (478, 320) (155, 539)
#  24%|██▍       | 166/682 [00:07<00:29, 17.46it/s]
# Right points r1 and r2, (495, 320) (834, 516)
# Left points l1 and l2, (475, 320) (156, 539)
# Right points r1 and r2, (495, 321) (876, 539)
# Left points l1 and l2, (468, 321) (161, 539)
# Right points r1 and r2, (505, 320) (878, 539)
# Left points l1 and l2, (465, 320) (156, 539)
# Right points r1 and r2, (495, 320) (879, 538)
# Left points l1 and l2, (468, 320) (157, 538)
#  25%|██▌       | 172/682 [00:08<00:30, 16.84it/s]
# Right points r1 and r2, (499, 320) (883, 539)
# Left points l1 and l2, (468, 320) (158, 539)
# Right points r1 and r2, (506, 320) (636, 400)
# Left points l1 and l2, (468, 320) (158, 539)
# Right points r1 and r2, (506, 320) (649, 407)
# Left points l1 and l2, (468, 320) (160, 539)
# Right points r1 and r2, (491, 320) (789, 483)
# Left points l1 and l2, (468, 320) (160, 538)
#  26%|██▌       | 175/682 [00:08<00:27, 18.60it/s]
# Right points r1 and r2, (506, 323) (840, 508)
# Left points l1 and l2, (467, 323) (164, 537)
# Right points r1 and r2, (523, 321) (706, 438)
# Left points l1 and l2, (463, 321) (162, 539)
# Right points r1 and r2, (523, 320) (735, 453)
# Left points l1 and l2, (466, 320) (164, 538)
# Right points r1 and r2, (522, 320) (771, 473)
# Left points l1 and l2, (468, 320) (165, 538)
# Right points r1 and r2, (514, 320) (819, 500)
# Left points l1 and l2, (468, 320) (168, 538)
#  27%|██▋       | 181/682 [00:08<00:25, 19.97it/s]
# Right points r1 and r2, (515, 320) (877, 537)
# Left points l1 and l2, (468, 320) (169, 539)
# Right points r1 and r2, (493, 320) (890, 538)
# Left points l1 and l2, (475, 320) (170, 539)
# Right points r1 and r2, (503, 320) (892, 538)
# Left points l1 and l2, (467, 320) (171, 539)
# Right points r1 and r2, (490, 320) (894, 539)
# Left points l1 and l2, (466, 320) (171, 539)
#  27%|██▋       | 184/682 [00:08<00:26, 18.76it/s]
# Right points r1 and r2, (491, 320) (637, 396)
# Left points l1 and l2, (466, 320) (171, 539)
# Right points r1 and r2, (495, 322) (648, 403)
# Left points l1 and l2, (465, 322) (171, 539)
# Right points r1 and r2, (497, 320) (661, 412)
# Left points l1 and l2, (467, 320) (171, 538)
# Right points r1 and r2, (492, 320) (823, 498)
# Left points l1 and l2, (473, 320) (174, 539)
#  27%|██▋       | 187/682 [00:09<00:25, 19.33it/s]
# Right points r1 and r2, (492, 320) (886, 533)
# Left points l1 and l2, (471, 320) (173, 538)
# Right points r1 and r2, (508, 320) (728, 448)
# Left points l1 and l2, (471, 320) (173, 539)
# Right points r1 and r2, (510, 321) (760, 466)
# Left points l1 and l2, (465, 321) (173, 539)
# Right points r1 and r2, (508, 320) (803, 489)
# Left points l1 and l2, (465, 320) (174, 539)
# Right points r1 and r2, (492, 323) (860, 521)
# Left points l1 and l2, (463, 323) (174, 539)
#  28%|██▊       | 193/682 [00:09<00:24, 20.16it/s]
# Right points r1 and r2, (492, 320) (894, 539)
# Left points l1 and l2, (463, 320) (174, 539)
# Right points r1 and r2, (493, 320) (894, 538)
# Left points l1 and l2, (464, 320) (173, 539)
# Right points r1 and r2, (486, 320) (895, 539)
# Left points l1 and l2, (463, 320) (173, 539)
# Right points r1 and r2, (491, 320) (898, 538)
# Left points l1 and l2, (463, 320) (172, 539)
# Right points r1 and r2, (492, 320) (636, 399)
# Left points l1 and l2, (462, 320) (171, 539)
#  29%|██▉       | 199/682 [00:09<00:24, 19.73it/s]
# Right points r1 and r2, (495, 320) (756, 459)
# Left points l1 and l2, (462, 320) (172, 539)
# Right points r1 and r2, (491, 322) (798, 485)
# Left points l1 and l2, (461, 322) (170, 539)
# Right points r1 and r2, (490, 320) (855, 517)
# Left points l1 and l2, (462, 320) (171, 539)
# Right points r1 and r2, (494, 320) (708, 439)
# Left points l1 and l2, (462, 320) (170, 539)
#  30%|██▉       | 202/682 [00:09<00:23, 20.39it/s]
# Right points r1 and r2, (490, 320) (776, 493)
# Left points l1 and l2, (467, 320) (181, 538)
# Right points r1 and r2, (505, 320) (772, 476)
# Left points l1 and l2, (462, 320) (167, 539)
# Right points r1 and r2, (495, 320) (821, 504)
# Left points l1 and l2, (461, 320) (166, 539)
# Right points r1 and r2, (505, 321) (885, 539)
# Left points l1 and l2, (461, 321) (167, 539)
# Right points r1 and r2, (487, 320) (881, 539)
# Left points l1 and l2, (466, 320) (166, 539)
#  30%|███       | 208/682 [00:10<00:23, 20.14it/s]
# Right points r1 and r2, (487, 320) (879, 538)
# Left points l1 and l2, (466, 320) (167, 539)
# Right points r1 and r2, (484, 320) (878, 539)
# Left points l1 and l2, (467, 320) (175, 538)
# Right points r1 and r2, (488, 320) (626, 398)
# Left points l1 and l2, (467, 320) (166, 538)
# Right points r1 and r2, (487, 320) (639, 405)
# Left points l1 and l2, (466, 320) (164, 539)
# Right points r1 and r2, (493, 320) (771, 473)
# Left points l1 and l2, (466, 320) (162, 539)
#  31%|███▏      | 214/682 [00:10<00:22, 20.99it/s]
# Right points r1 and r2, (486, 320) (820, 503)
# Left points l1 and l2, (460, 320) (160, 539)
# Right points r1 and r2, (486, 320) (886, 538)
# Left points l1 and l2, (459, 320) (160, 539)
# Right points r1 and r2, (486, 320) (715, 449)
# Left points l1 and l2, (459, 320) (159, 539)
# Right points r1 and r2, (485, 320) (747, 468)
# Left points l1 and l2, (457, 320) (158, 539)
# Right points r1 and r2, (493, 322) (790, 493)
# Left points l1 and l2, (459, 322) (159, 538)
#  32%|███▏      | 217/682 [00:10<00:22, 20.63it/s]
# Right points r1 and r2, (483, 320) (847, 526)
# Left points l1 and l2, (458, 320) (157, 538)
# Right points r1 and r2, (485, 320) (871, 538)
# Left points l1 and l2, (458, 320) (161, 539)
# Right points r1 and r2, (489, 320) (870, 538)
# Left points l1 and l2, (459, 320) (154, 539)
# Right points r1 and r2, (488, 320) (870, 539)
# Left points l1 and l2, (457, 320) (153, 538)
# Right points r1 and r2, (489, 320) (618, 395)
# Left points l1 and l2, (458, 320) (154, 538)
#  33%|███▎      | 223/682 [00:10<00:21, 21.21it/s]
# Right points r1 and r2, (486, 320) (630, 402)
# Left points l1 and l2, (464, 320) (152, 539)
# Right points r1 and r2, (489, 321) (750, 467)
# Left points l1 and l2, (458, 321) (151, 539)
# Right points r1 and r2, (492, 320) (794, 494)
# Left points l1 and l2, (459, 320) (151, 538)
# Right points r1 and r2, (491, 320) (853, 524)
# Left points l1 and l2, (458, 320) (151, 539)
# Right points r1 and r2, (487, 320) (701, 442)
# Left points l1 and l2, (457, 320) (151, 539)
#  33%|███▎      | 226/682 [00:10<00:21, 21.52it/s]
# Right points r1 and r2, (495, 320) (730, 460)
# Left points l1 and l2, (459, 320) (153, 539)
# Right points r1 and r2, (488, 320) (767, 482)
# Left points l1 and l2, (460, 320) (153, 539)
# Right points r1 and r2, (496, 321) (818, 510)
# Left points l1 and l2, (459, 321) (152, 538)
# Right points r1 and r2, (489, 320) (870, 539)
# Left points l1 and l2, (460, 320) (152, 539)
#  34%|███▍      | 232/682 [00:11<00:21, 21.09it/s]
# Right points r1 and r2, (494, 322) (867, 539)
# Left points l1 and l2, (459, 322) (151, 539)
# Right points r1 and r2, (499, 320) (873, 539)
# Left points l1 and l2, (458, 320) (150, 538)
# Right points r1 and r2, (493, 320) (872, 538)
# Left points l1 and l2, (460, 320) (149, 538)
# Right points r1 and r2, (486, 320) (628, 398)
# Left points l1 and l2, (460, 320) (147, 538)
# Right points r1 and r2, (494, 320) (640, 406)
# Left points l1 and l2, (460, 320) (147, 538)
#  35%|███▍      | 238/682 [00:11<00:20, 21.28it/s]
# Right points r1 and r2, (502, 320) (654, 414)
# Left points l1 and l2, (459, 320) (147, 539)
# Right points r1 and r2, (508, 320) (831, 517)
# Left points l1 and l2, (459, 320) (146, 539)
# Right points r1 and r2, (492, 320) (693, 437)
# Left points l1 and l2, (460, 320) (145, 539)
# Right points r1 and r2, (501, 320) (719, 452)
# Left points l1 and l2, (459, 320) (145, 539)
# Right points r1 and r2, (501, 320) (753, 472)
# Left points l1 and l2, (460, 320) (143, 538)
#  35%|███▌      | 241/682 [00:11<00:21, 20.93it/s]
# Right points r1 and r2, (504, 320) (798, 498)
# Left points l1 and l2, (460, 320) (153, 539)
# Right points r1 and r2, (487, 320) (861, 535)
# Left points l1 and l2, (459, 320) (144, 539)
# Right points r1 and r2, (490, 320) (870, 538)
# Left points l1 and l2, (460, 320) (145, 539)
# Right points r1 and r2, (486, 320) (871, 539)
# Left points l1 and l2, (460, 320) (145, 539)
# Right points r1 and r2, (501, 320) (871, 538)
# Left points l1 and l2, (460, 320) (143, 539)
#  36%|███▌      | 247/682 [00:11<00:20, 21.63it/s]
# Right points r1 and r2, (485, 320) (610, 387)
# Left points l1 and l2, (460, 320) (143, 539)
# Right points r1 and r2, (507, 320) (732, 456)
# Left points l1 and l2, (460, 320) (144, 539)
# Right points r1 and r2, (489, 320) (769, 478)
# Left points l1 and l2, (461, 320) (145, 539)
# Right points r1 and r2, (511, 322) (817, 507)
# Left points l1 and l2, (459, 322) (144, 539)
# Right points r1 and r2, (492, 321) (651, 417)
# Left points l1 and l2, (459, 321) (144, 539)
#  37%|███▋      | 250/682 [00:12<00:20, 21.41it/s]
# Right points r1 and r2, (489, 320) (677, 428)
# Left points l1 and l2, (460, 320) (143, 539)
# Right points r1 and r2, (490, 320) (699, 441)
# Left points l1 and l2, (460, 320) (143, 538)
# Right points r1 and r2, (491, 320) (727, 458)
# Left points l1 and l2, (459, 320) (143, 539)
# Right points r1 and r2, (490, 320) (764, 480)
# Left points l1 and l2, (459, 320) (145, 539)
# Right points r1 and r2, (491, 320) (812, 509)
# Left points l1 and l2, (460, 320) (150, 538)
#  38%|███▊      | 256/682 [00:12<00:19, 21.71it/s]
# Right points r1 and r2, (483, 320) (859, 539)
# Left points l1 and l2, (459, 320) (146, 539)
# Right points r1 and r2, (490, 320) (864, 538)
# Left points l1 and l2, (460, 320) (148, 539)
# Right points r1 and r2, (486, 321) (865, 539)
# Left points l1 and l2, (458, 321) (149, 539)
# Right points r1 and r2, (487, 320) (864, 538)
# Left points l1 and l2, (459, 320) (150, 539)
# Right points r1 and r2, (488, 320) (616, 393)
# Left points l1 and l2, (460, 320) (151, 539)
#  38%|███▊      | 262/682 [00:12<00:18, 22.17it/s]
# Right points r1 and r2, (485, 320) (627, 399)
# Left points l1 and l2, (460, 320) (152, 539)
# Right points r1 and r2, (490, 320) (640, 407)
# Left points l1 and l2, (459, 320) (151, 538)
# Right points r1 and r2, (486, 321) (654, 416)
# Left points l1 and l2, (460, 321) (150, 539)
# Right points r1 and r2, (485, 320) (827, 519)
# Left points l1 and l2, (459, 320) (152, 538)
# Right points r1 and r2, (487, 322) (695, 439)
# Left points l1 and l2, (459, 322) (151, 538)
#  39%|███▉      | 268/682 [00:12<00:18, 21.87it/s]
# Right points r1 and r2, (487, 320) (723, 455)
# Left points l1 and l2, (460, 320) (149, 538)
# Right points r1 and r2, (486, 321) (759, 475)
# Left points l1 and l2, (459, 321) (148, 538)
# Right points r1 and r2, (487, 320) (806, 504)
# Left points l1 and l2, (461, 320) (148, 539)
# Right points r1 and r2, (487, 321) (869, 538)
# Left points l1 and l2, (460, 321) (148, 539)
# Right points r1 and r2, (491, 320) (869, 539)
# Left points l1 and l2, (460, 320) (148, 539)
#  40%|███▉      | 271/682 [00:13<00:18, 21.87it/s]
# Right points r1 and r2, (496, 321) (869, 539)
# Left points l1 and l2, (460, 321) (149, 539)
# Right points r1 and r2, (499, 325) (870, 539)
# Left points l1 and l2, (458, 325) (150, 539)
# Right points r1 and r2, (490, 322) (629, 397)
# Left points l1 and l2, (461, 322) (149, 539)
# Right points r1 and r2, (492, 322) (642, 404)
# Left points l1 and l2, (461, 322) (151, 539)
# Right points r1 and r2, (489, 322) (771, 476)
# Left points l1 and l2, (461, 322) (151, 539)
#  41%|████      | 277/682 [00:13<00:18, 21.53it/s]
# Right points r1 and r2, (489, 322) (820, 505)
# Left points l1 and l2, (461, 322) (153, 538)
# Right points r1 and r2, (487, 320) (696, 435)
# Left points l1 and l2, (471, 320) (153, 538)
# Right points r1 and r2, (489, 322) (722, 450)
# Left points l1 and l2, (461, 322) (153, 538)
# Right points r1 and r2, (490, 321) (756, 469)
# Left points l1 and l2, (461, 321) (153, 538)
# Right points r1 and r2, (490, 322) (801, 495)
# Left points l1 and l2, (461, 322) (151, 538)
#  41%|████▏     | 283/682 [00:13<00:18, 21.92it/s]
# Right points r1 and r2, (489, 322) (863, 532)
# Left points l1 and l2, (460, 322) (152, 539)
# Right points r1 and r2, (485, 320) (875, 538)
# Left points l1 and l2, (460, 320) (152, 539)
# Right points r1 and r2, (484, 320) (875, 538)
# Left points l1 and l2, (459, 320) (153, 539)
# Right points r1 and r2, (481, 320) (874, 539)
# Left points l1 and l2, (466, 320) (154, 538)
# Right points r1 and r2, (486, 320) (625, 398)
# Left points l1 and l2, (479, 320) (155, 539)
#  42%|████▏     | 286/682 [00:13<00:18, 21.98it/s]
# Right points r1 and r2, (482, 320) (636, 405)
# Left points l1 and l2, (458, 320) (155, 539)
# Right points r1 and r2, (482, 320) (762, 474)
# Left points l1 and l2, (459, 320) (154, 539)
# Right points r1 and r2, (487, 320) (807, 500)
# Left points l1 and l2, (458, 320) (154, 539)
# Right points r1 and r2, (490, 320) (874, 538)
# Left points l1 and l2, (458, 320) (153, 539)
# Right points r1 and r2, (481, 320) (710, 450)
# Left points l1 and l2, (479, 320) (154, 538)
#  43%|████▎     | 292/682 [00:13<00:18, 21.29it/s]
# Right points r1 and r2, (481, 320) (742, 469)
# Left points l1 and l2, (473, 320) (156, 539)
# Right points r1 and r2, (481, 321) (782, 494)
# Left points l1 and l2, (457, 321) (157, 539)
# Right points r1 and r2, (483, 320) (838, 526)
# Left points l1 and l2, (479, 320) (136, 539)
# Right points r1 and r2, (487, 320) (864, 538)
# Left points l1 and l2, (466, 320) (74, 539)
# Right points r1 and r2, (483, 320) (865, 538)
# Left points l1 and l2, (457, 320) (154, 538)
# Right points r1 and r2, (490, 320) (867, 539)
# Left points l1 and l2, (456, 320) (154, 539)
# Right points r1 and r2, (488, 322) (618, 397)
# Left points l1 and l2, (457, 322) (153, 539)
#  44%|████▍     | 299/682 [00:14<00:27, 13.70it/s]
# Right points r1 and r2, (491, 320) (629, 402)
# Left points l1 and l2, (457, 320) (154, 539)
# Right points r1 and r2, (487, 320) (750, 469)
# Left points l1 and l2, (457, 320) (154, 539)
# Right points r1 and r2, (490, 320) (789, 493)
# Left points l1 and l2, (457, 320) (154, 539)
# Right points r1 and r2, (488, 321) (853, 531)
# Left points l1 and l2, (457, 321) (154, 539)
#  44%|████▍     | 301/682 [00:14<00:26, 14.18it/s]
# Right points r1 and r2, (488, 321) (699, 445)
# Left points l1 and l2, (457, 321) (155, 539)
# Right points r1 and r2, (492, 321) (728, 462)
# Left points l1 and l2, (456, 321) (155, 538)
# Right points r1 and r2, (492, 321) (766, 484)
# Left points l1 and l2, (457, 321) (155, 538)
# Right points r1 and r2, (489, 322) (817, 511)
# Left points l1 and l2, (456, 322) (155, 539)
#  45%|████▍     | 305/682 [00:15<00:26, 14.26it/s]
# Right points r1 and r2, (495, 322) (862, 539)
# Left points l1 and l2, (456, 322) (153, 539)
# Right points r1 and r2, (496, 321) (860, 539)
# Left points l1 and l2, (456, 321) (153, 539)
# Right points r1 and r2, (488, 320) (859, 539)
# Left points l1 and l2, (455, 320) (151, 539)
#  45%|████▌     | 309/682 [00:15<00:24, 15.51it/s]
# Right points r1 and r2, (489, 320) (619, 393)
# Left points l1 and l2, (456, 320) (152, 539)
# Right points r1 and r2, (492, 320) (629, 399)
# Left points l1 and l2, (456, 320) (151, 539)
# Right points r1 and r2, (497, 320) (642, 407)
# Left points l1 and l2, (456, 320) (149, 538)
# Right points r1 and r2, (489, 320) (781, 487)
# Left points l1 and l2, (456, 320) (149, 538)
#  46%|████▌     | 313/682 [00:15<00:22, 16.09it/s]
# Right points r1 and r2, (491, 320) (834, 521)
# Left points l1 and l2, (456, 320) (146, 539)
# Right points r1 and r2, (496, 320) (698, 440)
# Left points l1 and l2, (456, 320) (145, 538)
# Right points r1 and r2, (505, 321) (725, 456)
# Left points l1 and l2, (455, 321) (145, 539)
# Right points r1 and r2, (490, 320) (760, 478)
# Left points l1 and l2, (455, 320) (144, 539)
#  46%|████▋     | 317/682 [00:15<00:21, 16.75it/s]
# Right points r1 and r2, (488, 321) (808, 507)
# Left points l1 and l2, (456, 321) (145, 539)
# Right points r1 and r2, (491, 320) (860, 539)
# Left points l1 and l2, (455, 320) (146, 539)
# Right points r1 and r2, (488, 320) (856, 538)
# Left points l1 and l2, (454, 320) (147, 539)
# Right points r1 and r2, (483, 320) (868, 539)
# Left points l1 and l2, (455, 320) (147, 538)
#  47%|████▋     | 321/682 [00:16<00:23, 15.31it/s]
# Right points r1 and r2, (490, 320) (867, 538)
# Left points l1 and l2, (454, 320) (86, 539)
# Right points r1 and r2, (490, 320) (627, 398)
# Left points l1 and l2, (454, 320) (147, 539)
# Right points r1 and r2, (482, 320) (735, 457)
# Left points l1 and l2, (454, 320) (146, 538)
#  47%|████▋     | 323/682 [00:16<00:25, 14.18it/s]
# Right points r1 and r2, (491, 320) (773, 481)
# Left points l1 and l2, (454, 320) (147, 539)
# Right points r1 and r2, (483, 320) (826, 512)
# Left points l1 and l2, (454, 320) (146, 539)
# Right points r1 and r2, (486, 320) (695, 438)
# Left points l1 and l2, (454, 320) (146, 539)
#  48%|████▊     | 325/682 [00:16<00:27, 13.08it/s]
# Right points r1 and r2, (490, 320) (722, 455)
# Left points l1 and l2, (479, 320) (146, 539)
# Right points r1 and r2, (488, 320) (759, 476)
# Left points l1 and l2, (453, 320) (146, 539)
#  48%|████▊     | 329/682 [00:17<00:43,  8.10it/s]
# Right points r1 and r2, (486, 320) (805, 505)
# Left points l1 and l2, (478, 320) (146, 539)
# Right points r1 and r2, (489, 321) (864, 539)
# Left points l1 and l2, (479, 321) (146, 539)
# Right points r1 and r2, (486, 320) (865, 539)
# Left points l1 and l2, (479, 320) (145, 539)
#  49%|████▊     | 331/682 [00:17<00:40,  8.62it/s]
# Right points r1 and r2, (481, 320) (867, 539)
# Left points l1 and l2, (454, 320) (143, 539)
# Right points r1 and r2, (487, 320) (868, 539)
# Left points l1 and l2, (453, 320) (141, 539)
# Right points r1 and r2, (484, 320) (622, 396)
# Left points l1 and l2, (453, 320) (140, 539)
#  49%|████▉     | 333/682 [00:17<00:36,  9.66it/s]
# Right points r1 and r2, (482, 320) (634, 404)
# Left points l1 and l2, (454, 320) (140, 538)
# Right points r1 and r2, (491, 321) (758, 478)
# Left points l1 and l2, (453, 321) (138, 539)
#  49%|████▉     | 337/682 [00:17<00:32, 10.58it/s]
# Right points r1 and r2, (481, 320) (805, 505)
# Left points l1 and l2, (479, 320) (138, 539)
# Right points r1 and r2, (485, 320) (687, 437)
# Left points l1 and l2, (452, 320) (137, 539)
# Right points r1 and r2, (485, 320) (714, 453)
# Left points l1 and l2, (478, 320) (137, 539)
#  50%|████▉     | 339/682 [00:18<00:33, 10.11it/s]
# Right points r1 and r2, (489, 321) (748, 472)
# Left points l1 and l2, (479, 321) (136, 538)
# Right points r1 and r2, (482, 320) (790, 499)
# Left points l1 and l2, (453, 320) (136, 539)
# Right points r1 and r2, (485, 320) (855, 537)
# Left points l1 and l2, (452, 320) (136, 538)
#  50%|█████     | 343/682 [00:18<00:29, 11.52it/s]
# Right points r1 and r2, (486, 320) (860, 538)
# Left points l1 and l2, (451, 320) (137, 539)
# Right points r1 and r2, (482, 320) (861, 539)
# Left points l1 and l2, (451, 320) (139, 538)
# Right points r1 and r2, (481, 320) (860, 539)
# Left points l1 and l2, (451, 320) (137, 539)
# Right points r1 and r2, (488, 320) (619, 396)
# Left points l1 and l2, (452, 320) (136, 539)
#  51%|█████     | 345/682 [00:18<00:26, 12.57it/s]
# Right points r1 and r2, (489, 320) (630, 403)
# Left points l1 and l2, (452, 320) (137, 538)
# Right points r1 and r2, (487, 320) (752, 473)
# Left points l1 and l2, (454, 320) (137, 539)
#  51%|█████     | 349/682 [00:19<00:30, 10.74it/s]
# Right points r1 and r2, (486, 320) (799, 502)
# Left points l1 and l2, (479, 320) (138, 539)
# Right points r1 and r2, (481, 320) (861, 537)
# Left points l1 and l2, (453, 320) (139, 538)
# Right points r1 and r2, (488, 320) (706, 449)
# Left points l1 and l2, (452, 320) (139, 539)
#  51%|█████▏    | 351/682 [00:19<00:31, 10.51it/s]
# Right points r1 and r2, (486, 320) (738, 468)
# Left points l1 and l2, (477, 320) (140, 539)
# Right points r1 and r2, (481, 320) (780, 493)
# Left points l1 and l2, (451, 320) (140, 539)
#  52%|█████▏    | 353/682 [00:19<00:34,  9.41it/s]
# Right points r1 and r2, (482, 320) (837, 528)
# Left points l1 and l2, (452, 320) (139, 539)
# Right points r1 and r2, (485, 320) (858, 539)
# Left points l1 and l2, (450, 320) (139, 539)
#  52%|█████▏    | 355/682 [00:19<00:35,  9.11it/s]
# Right points r1 and r2, (487, 320) (858, 538)
# Left points l1 and l2, (478, 320) (138, 539)
# Right points r1 and r2, (487, 320) (857, 538)
# Left points l1 and l2, (452, 320) (138, 539)
#  52%|█████▏    | 357/682 [00:19<00:34,  9.37it/s]
# Right points r1 and r2, (488, 320) (618, 395)
# Left points l1 and l2, (477, 320) (139, 539)
# Right points r1 and r2, (486, 320) (629, 402)
# Left points l1 and l2, (453, 320) (138, 539)
#  52%|█████▏    | 358/682 [00:20<00:35,  9.21it/s]
# Right points r1 and r2, (489, 320) (642, 409)
# Left points l1 and l2, (478, 320) (155, 538)
# Right points r1 and r2, (487, 320) (788, 498)
# Left points l1 and l2, (478, 320) (136, 539)
# Right points r1 and r2, (487, 320) (850, 537)
# Left points l1 and l2, (451, 320) (135, 539)
#  53%|█████▎    | 364/682 [00:20<00:26, 11.99it/s]
# Right points r1 and r2, (486, 320) (700, 446)
# Left points l1 and l2, (478, 320) (135, 539)
# Right points r1 and r2, (484, 320) (731, 464)
# Left points l1 and l2, (479, 320) (137, 539)
# Right points r1 and r2, (486, 320) (771, 488)
# Left points l1 and l2, (478, 320) (138, 539)
# Right points r1 and r2, (481, 320) (825, 521)
# Left points l1 and l2, (450, 320) (140, 539)
#  54%|█████▎    | 366/682 [00:20<00:26, 12.07it/s]
# Right points r1 and r2, (485, 320) (858, 539)
# Left points l1 and l2, (478, 320) (140, 539)
# Right points r1 and r2, (485, 320) (858, 538)
# Left points l1 and l2, (477, 320) (141, 539)
# Right points r1 and r2, (481, 320) (858, 538)
# Left points l1 and l2, (478, 320) (142, 539)
# Right points r1 and r2, (487, 320) (725, 433)
# Left points l1 and l2, (477, 320) (143, 538)
#  54%|█████▍    | 370/682 [00:20<00:23, 13.39it/s]
# Right points r1 and r2, (487, 320) (758, 448)
# Left points l1 and l2, (478, 320) (143, 539)
# Right points r1 and r2, (483, 320) (796, 467)
# Left points l1 and l2, (452, 320) (144, 539)
# Right points r1 and r2, (482, 320) (841, 491)
# Left points l1 and l2, (453, 320) (142, 539)
# Right points r1 and r2, (486, 320) (914, 528)
# Left points l1 and l2, (453, 320) (142, 538)
#  55%|█████▍    | 374/682 [00:21<00:22, 13.98it/s]
# Right points r1 and r2, (487, 320) (695, 443)
# Left points l1 and l2, (453, 320) (150, 539)
# Right points r1 and r2, (486, 320) (724, 461)
# Left points l1 and l2, (448, 320) (143, 539)
# Right points r1 and r2, (482, 320) (761, 484)
# Left points l1 and l2, (453, 320) (143, 539)
#  55%|█████▌    | 378/682 [00:21<00:22, 13.65it/s]
# Right points r1 and r2, (481, 320) (813, 515)
# Left points l1 and l2, (453, 320) (143, 539)
# Right points r1 and r2, (488, 323) (856, 539)
# Left points l1 and l2, (451, 323) (141, 538)
# Right points r1 and r2, (481, 320) (857, 539)
# Left points l1 and l2, (452, 320) (138, 539)
#  56%|█████▌    | 380/682 [00:21<00:22, 13.49it/s]
# Right points r1 and r2, (483, 320) (857, 539)
# Left points l1 and l2, (453, 320) (151, 539)
# Right points r1 and r2, (485, 320) (851, 535)
# Left points l1 and l2, (451, 320) (136, 538)
# Right points r1 and r2, (484, 320) (621, 399)
# Left points l1 and l2, (454, 320) (137, 539)
#  56%|█████▋    | 384/682 [00:21<00:20, 14.61it/s]
# Right points r1 and r2, (484, 320) (630, 407)
# Left points l1 and l2, (455, 320) (137, 539)
# Right points r1 and r2, (481, 320) (649, 416)
# Left points l1 and l2, (455, 320) (137, 538)
# Right points r1 and r2, (487, 320) (668, 427)
# Left points l1 and l2, (455, 320) (134, 539)
# Right points r1 and r2, (485, 320) (690, 440)
# Left points l1 and l2, (455, 320) (134, 539)
#  57%|█████▋    | 388/682 [00:22<00:18, 15.56it/s]
# Right points r1 and r2, (486, 320) (717, 457)
# Left points l1 and l2, (456, 320) (135, 539)
# Right points r1 and r2, (485, 320) (754, 478)
# Left points l1 and l2, (456, 320) (134, 539)
# Right points r1 and r2, (485, 320) (801, 507)
# Left points l1 and l2, (455, 320) (134, 539)
# Right points r1 and r2, (488, 320) (857, 539)
# Left points l1 and l2, (455, 320) (133, 539)
#  57%|█████▋    | 392/682 [00:22<00:18, 15.79it/s]
# Right points r1 and r2, (485, 320) (846, 539)
# Left points l1 and l2, (456, 320) (132, 539)
# Right points r1 and r2, (483, 320) (853, 539)
# Left points l1 and l2, (452, 320) (133, 539)
# Right points r1 and r2, (491, 320) (852, 539)
# Left points l1 and l2, (457, 320) (133, 539)
# Right points r1 and r2, (485, 320) (617, 398)
# Left points l1 and l2, (454, 320) (133, 539)
#  58%|█████▊    | 396/682 [00:22<00:17, 16.15it/s]
# Right points r1 and r2, (485, 320) (629, 405)
# Left points l1 and l2, (457, 320) (132, 539)
# Right points r1 and r2, (485, 320) (643, 414)
# Left points l1 and l2, (457, 320) (133, 539)
# Right points r1 and r2, (485, 320) (659, 425)
# Left points l1 and l2, (457, 320) (133, 539)
# Right points r1 and r2, (486, 320) (681, 438)
# Left points l1 and l2, (457, 320) (132, 538)
#  59%|█████▊    | 400/682 [00:22<00:17, 16.50it/s]
# Right points r1 and r2, (490, 320) (707, 454)
# Left points l1 and l2, (457, 320) (131, 539)
# Right points r1 and r2, (486, 320) (740, 475)
# Left points l1 and l2, (458, 320) (138, 538)
# Right points r1 and r2, (488, 320) (783, 503)
# Left points l1 and l2, (458, 320) (130, 539)
# Right points r1 and r2, (485, 320) (842, 539)
# Left points l1 and l2, (453, 320) (129, 538)
#  59%|█████▉    | 404/682 [00:23<00:17, 16.24it/s]
# Right points r1 and r2, (486, 320) (842, 539)
# Left points l1 and l2, (456, 320) (130, 539)
# Right points r1 and r2, (487, 320) (842, 538)
# Left points l1 and l2, (455, 320) (128, 539)
# Right points r1 and r2, (487, 320) (841, 538)
# Left points l1 and l2, (459, 320) (99, 539)
# Right points r1 and r2, (484, 320) (616, 398)
# Left points l1 and l2, (456, 320) (128, 538)
#  60%|█████▉    | 408/682 [00:23<00:16, 16.45it/s]
# Right points r1 and r2, (487, 320) (627, 405)
# Left points l1 and l2, (459, 320) (128, 538)
# Right points r1 and r2, (485, 320) (640, 414)
# Left points l1 and l2, (458, 320) (129, 539)
# Right points r1 and r2, (490, 321) (657, 424)
# Left points l1 and l2, (458, 321) (133, 537)
#  60%|██████    | 412/682 [00:23<00:17, 15.74it/s]
# Right points r1 and r2, (490, 320) (676, 437)
# Left points l1 and l2, (459, 320) (131, 539)
# Right points r1 and r2, (486, 320) (701, 452)
# Left points l1 and l2, (459, 320) (132, 539)
# Right points r1 and r2, (486, 320) (729, 471)
# Left points l1 and l2, (459, 320) (131, 539)
# Right points r1 and r2, (489, 320) (775, 497)
# Left points l1 and l2, (458, 320) (130, 539)
#  61%|██████    | 416/682 [00:23<00:16, 16.43it/s]
# Right points r1 and r2, (491, 320) (833, 533)
# Left points l1 and l2, (456, 320) (130, 539)
# Right points r1 and r2, (490, 320) (848, 539)
# Left points l1 and l2, (459, 320) (132, 539)
# Right points r1 and r2, (499, 320) (850, 539)
# Left points l1 and l2, (459, 320) (132, 539)
# Right points r1 and r2, (490, 320) (851, 539)
# Left points l1 and l2, (461, 320) (132, 539)
#  61%|██████▏   | 418/682 [00:24<00:16, 16.39it/s]
# Right points r1 and r2, (490, 320) (618, 395)
# Left points l1 and l2, (461, 320) (134, 539)
# Right points r1 and r2, (489, 320) (628, 402)
# Left points l1 and l2, (462, 320) (133, 539)
# Right points r1 and r2, (488, 320) (740, 470)
# Left points l1 and l2, (462, 320) (135, 539)
# Right points r1 and r2, (490, 320) (785, 496)
# Left points l1 and l2, (462, 320) (135, 539)
#  62%|██████▏   | 423/682 [00:24<00:16, 15.90it/s]
# Right points r1 and r2, (487, 320) (845, 535)
# Left points l1 and l2, (462, 320) (136, 539)
# Right points r1 and r2, (490, 320) (702, 448)
# Left points l1 and l2, (462, 320) (141, 539)
# Right points r1 and r2, (491, 320) (733, 466)
# Left points l1 and l2, (462, 320) (133, 538)
# Right points r1 and r2, (497, 322) (773, 491)
#  62%|██████▏   | 425/682 [00:24<00:16, 15.25it/s]
# Left points l1 and l2, (460, 322) (134, 539)
# Right points r1 and r2, (492, 320) (829, 526)
# Left points l1 and l2, (462, 320) (133, 539)
# Right points r1 and r2, (491, 320) (853, 539)
# Left points l1 and l2, (461, 320) (135, 539)
#  63%|██████▎   | 429/682 [00:24<00:16, 15.51it/s]
# Right points r1 and r2, (491, 320) (851, 539)
# Left points l1 and l2, (466, 320) (136, 539)
# Right points r1 and r2, (489, 320) (850, 539)
# Left points l1 and l2, (462, 320) (136, 539)
# Right points r1 and r2, (490, 320) (615, 395)
# Left points l1 and l2, (462, 320) (136, 539)
# Right points r1 and r2, (497, 320) (625, 402)
# Left points l1 and l2, (462, 320) (136, 539)
#  64%|██████▎   | 434/682 [00:24<00:14, 17.25it/s]
# Right points r1 and r2, (490, 320) (638, 410)
# Left points l1 and l2, (460, 320) (136, 538)
# Right points r1 and r2, (491, 320) (758, 479)
# Left points l1 and l2, (460, 320) (135, 539)
# Right points r1 and r2, (491, 320) (673, 431)
# Left points l1 and l2, (460, 320) (134, 539)
# Right points r1 and r2, (490, 320) (696, 445)
# Left points l1 and l2, (460, 320) (134, 539)
#  64%|██████▍   | 438/682 [00:25<00:15, 16.20it/s]
# Right points r1 and r2, (491, 320) (725, 463)
# Left points l1 and l2, (461, 320) (133, 539)
# Right points r1 and r2, (489, 320) (763, 487)
# Left points l1 and l2, (458, 320) (133, 539)
# Right points r1 and r2, (490, 320) (815, 519)
# Left points l1 and l2, (459, 320) (132, 539)
# Right points r1 and r2, (495, 320) (850, 538)
# Left points l1 and l2, (461, 320) (133, 539)
#  65%|██████▍   | 442/682 [00:25<00:14, 16.09it/s]
# Right points r1 and r2, (491, 320) (853, 539)
# Left points l1 and l2, (459, 320) (133, 539)
# Right points r1 and r2, (491, 320) (856, 539)
# Left points l1 and l2, (460, 320) (132, 539)
# Right points r1 and r2, (501, 320) (858, 537)
# Left points l1 and l2, (453, 320) (69, 539)
# Right points r1 and r2, (501, 320) (613, 391)
# Left points l1 and l2, (459, 320) (129, 539)
#  65%|██████▌   | 446/682 [00:25<00:14, 16.68it/s]
# Right points r1 and r2, (503, 323) (624, 398)
# Left points l1 and l2, (455, 323) (128, 539)
# Right points r1 and r2, (505, 320) (735, 463)
# Left points l1 and l2, (454, 320) (128, 539)
# Right points r1 and r2, (491, 320) (777, 491)
# Left points l1 and l2, (455, 320) (128, 539)
# Right points r1 and r2, (488, 320) (831, 529)
# Left points l1 and l2, (456, 320) (130, 539)
#  66%|██████▌   | 449/682 [00:25<00:13, 17.68it/s]
# Right points r1 and r2, (487, 320) (690, 441)
# Left points l1 and l2, (456, 320) (130, 539)
# Right points r1 and r2, (491, 320) (717, 456)
# Left points l1 and l2, (459, 320) (127, 539)
# Right points r1 and r2, (491, 320) (753, 477)
# Left points l1 and l2, (459, 320) (127, 538)
# Right points r1 and r2, (512, 320) (799, 505)
# Left points l1 and l2, (458, 320) (127, 539)
# Right points r1 and r2, (507, 320) (860, 539)
# Left points l1 and l2, (457, 320) (128, 539)
#  67%|██████▋   | 455/682 [00:26<00:11, 19.29it/s]
# Right points r1 and r2, (506, 325) (858, 538)
# Left points l1 and l2, (450, 325) (129, 538)
# Right points r1 and r2, (518, 320) (858, 538)
# Left points l1 and l2, (459, 320) (84, 539)
# Right points r1 and r2, (510, 320) (859, 539)
# Left points l1 and l2, (458, 320) (125, 539)
# Right points r1 and r2, (525, 320) (620, 394)
# Left points l1 and l2, (457, 320) (125, 539)
# Right points r1 and r2, (522, 320) (631, 401)
# Left points l1 and l2, (458, 320) (124, 538)
#  67%|██████▋   | 458/682 [00:26<00:11, 20.03it/s]
# Right points r1 and r2, (506, 320) (755, 475)
# Left points l1 and l2, (457, 320) (124, 538)
# Right points r1 and r2, (491, 320) (800, 509)
# Left points l1 and l2, (461, 320) (124, 538)
# Right points r1 and r2, (489, 320) (684, 436)
# Left points l1 and l2, (459, 320) (126, 538)
# Right points r1 and r2, (501, 321) (709, 451)
# Left points l1 and l2, (461, 321) (123, 539)
#  68%|██████▊   | 464/682 [00:26<00:10, 20.62it/s]
# Right points r1 and r2, (493, 320) (742, 471)
# Left points l1 and l2, (456, 320) (132, 538)
# Right points r1 and r2, (501, 320) (785, 498)
# ...
# Right points r1 and r2, (512, 320) (693, 439)
# Left points l1 and l2, (473, 320) (139, 538)
# Right points r1 and r2, (512, 320) (720, 455)
# Left points l1 and l2, (472, 320) (139, 538)
#  79%|███████▊  | 537/682 [00:31<00:10, 14.42it/s]
# Right points r1 and r2, (512, 320) (754, 476)
# Left points l1 and l2, (472, 320) (138, 539)
# Right points r1 and r2, (512, 320) (799, 505)
# Left points l1 and l2, (472, 320) (139, 539)
# Right points r1 and r2, (508, 320) (857, 539)
# Left points l1 and l2, (473, 320) (141, 539)
#  79%|███████▉  | 539/682 [00:31<00:11, 12.45it/s]
# Right points r1 and r2, (510, 320) (854, 539)
# Left points l1 and l2, (473, 320) (142, 539)
# Right points r1 and r2, (508, 320) (856, 539)
# Left points l1 and l2, (473, 320) (143, 539)
#  79%|███████▉  | 541/682 [00:31<00:12, 11.66it/s]
# Right points r1 and r2, (510, 320) (855, 539)
# Left points l1 and l2, (472, 320) (143, 538)
# Right points r1 and r2, (526, 320) (622, 397)
# Left points l1 and l2, (472, 320) (144, 538)
# Right points r1 and r2, (516, 320) (726, 454)
# Left points l1 and l2, (471, 320) (143, 538)
#  80%|███████▉  | 545/682 [00:32<00:12, 11.19it/s]
# Right points r1 and r2, (529, 320) (759, 476)
# Left points l1 and l2, (470, 320) (143, 538)
# Right points r1 and r2, (530, 320) (810, 507)
# Left points l1 and l2, (470, 320) (143, 539)
# Right points r1 and r2, (532, 320) (685, 434)
# Left points l1 and l2, (470, 320) (143, 539)
#  80%|████████  | 547/682 [00:32<00:12, 11.02it/s]
# Right points r1 and r2, (520, 320) (711, 449)
# Left points l1 and l2, (470, 320) (145, 539)
# Right points r1 and r2, (534, 320) (742, 467)
# Left points l1 and l2, (469, 320) (144, 538)
# Right points r1 and r2, (535, 320) (785, 492)
# Left points l1 and l2, (469, 320) (144, 539)
#  80%|████████  | 549/682 [00:32<00:11, 11.10it/s]
# Right points r1 and r2, (537, 320) (842, 526)
# Left points l1 and l2, (468, 320) (144, 539)
# Right points r1 and r2, (538, 320) (864, 539)
# Left points l1 and l2, (467, 320) (144, 539)
# Right points r1 and r2, (540, 320) (864, 539)
# Left points l1 and l2, (468, 320) (145, 539)
#  81%|████████  | 553/682 [00:32<00:11, 10.93it/s]
# Right points r1 and r2, (527, 320) (862, 539)
# Left points l1 and l2, (467, 320) (146, 539)
# Right points r1 and r2, (525, 320) (622, 394)
# Left points l1 and l2, (468, 320) (146, 539)
#  81%|████████▏ | 555/682 [00:33<00:14,  9.07it/s]
# Right points r1 and r2, (527, 320) (633, 402)
# Left points l1 and l2, (470, 320) (147, 539)
# Right points r1 and r2, (528, 320) (647, 410)
# Left points l1 and l2, (471, 320) (149, 539)
#  82%|████████▏ | 556/682 [00:33<00:15,  8.07it/s]
# Right points r1 and r2, (531, 320) (793, 495)
# Left points l1 and l2, (470, 320) (149, 539)
# Right points r1 and r2, (530, 320) (851, 526)
# Left points l1 and l2, (468, 320) (148, 539)
#  82%|████████▏ | 559/682 [00:33<00:18,  6.50it/s]
# Right points r1 and r2, (535, 320) (706, 443)
# Left points l1 and l2, (467, 320) (147, 539)
# Right points r1 and r2, (537, 320) (736, 460)
# Left points l1 and l2, (468, 320) (146, 539)
#  82%|████████▏ | 561/682 [00:34<00:16,  7.23it/s]
# Right points r1 and r2, (538, 320) (775, 483)
# Left points l1 and l2, (468, 320) (148, 539)
# Right points r1 and r2, (537, 320) (826, 513)
# Left points l1 and l2, (469, 320) (146, 539)
#  83%|████████▎ | 563/682 [00:34<00:14,  8.13it/s]
# Right points r1 and r2, (539, 320) (871, 539)
# Left points l1 and l2, (470, 320) (148, 538)
# Right points r1 and r2, (540, 320) (873, 539)
# Left points l1 and l2, (469, 320) (146, 539)
# Right points r1 and r2, (542, 320) (873, 538)
# Left points l1 and l2, (470, 320) (149, 539)
#  83%|████████▎ | 565/682 [00:34<00:13,  8.72it/s]
# Right points r1 and r2, (546, 320) (876, 539)
# Left points l1 and l2, (469, 320) (150, 538)
# Right points r1 and r2, (547, 320) (634, 397)
# Left points l1 and l2, (469, 320) (150, 538)
# Right points r1 and r2, (550, 320) (745, 460)
# Left points l1 and l2, (467, 320) (152, 539)
#  83%|████████▎ | 569/682 [00:34<00:11,  9.74it/s]
# Right points r1 and r2, (552, 320) (785, 484)
# Left points l1 and l2, (468, 320) (153, 539)
# Right points r1 and r2, (544, 320) (839, 514)
# Left points l1 and l2, (465, 320) (155, 539)
# Right points r1 and r2, (547, 320) (703, 437)
# Left points l1 and l2, (466, 320) (156, 539)
#  84%|████████▍ | 572/682 [00:35<00:11,  9.73it/s]
# Right points r1 and r2, (538, 320) (731, 453)
# Left points l1 and l2, (471, 320) (158, 538)
# Right points r1 and r2, (540, 320) (766, 472)
# Left points l1 and l2, (467, 320) (158, 539)
# Right points r1 and r2, (538, 320) (812, 500)
# Left points l1 and l2, (471, 320) (160, 539)
#  84%|████████▍ | 576/682 [00:35<00:09, 11.00it/s]
# Right points r1 and r2, (540, 322) (878, 537)
# Left points l1 and l2, (463, 322) (163, 539)
# Right points r1 and r2, (542, 320) (883, 538)
# Left points l1 and l2, (468, 320) (165, 539)
# Right points r1 and r2, (548, 320) (884, 539)
# Left points l1 and l2, (471, 320) (177, 539)
#  85%|████████▍ | 578/682 [00:35<00:09, 10.77it/s]
# Right points r1 and r2, (550, 320) (886, 539)
# Left points l1 and l2, (470, 320) (165, 539)
# Right points r1 and r2, (548, 320) (631, 393)
# Left points l1 and l2, (467, 320) (165, 539)
# Right points r1 and r2, (557, 320) (732, 447)
# Left points l1 and l2, (467, 320) (164, 539)
#  85%|████████▌ | 580/682 [00:35<00:08, 11.45it/s]
# Right points r1 and r2, (553, 320) (657, 407)
# Left points l1 and l2, (465, 320) (164, 539)
# Right points r1 and r2, (556, 320) (816, 494)
# Left points l1 and l2, (466, 320) (165, 538)
# Right points r1 and r2, (559, 320) (883, 535)
# Left points l1 and l2, (471, 320) (170, 538)
#  85%|████████▌ | 582/682 [00:36<00:08, 11.16it/s]
# Right points r1 and r2, (550, 320) (719, 443)
# Left points l1 and l2, (472, 320) (167, 538)
# Right points r1 and r2, (552, 320) (752, 462)
# Left points l1 and l2, (472, 320) (171, 539)
#  86%|████████▌ | 586/682 [00:36<00:09,  9.96it/s]
# Right points r1 and r2, (540, 320) (794, 486)
# Left points l1 and l2, (472, 320) (170, 539)
# Right points r1 and r2, (540, 320) (850, 518)
# Left points l1 and l2, (472, 320) (170, 539)
# Right points r1 and r2, (542, 320) (889, 539)
# Left points l1 and l2, (473, 320) (170, 537)
#  87%|████████▋ | 590/682 [00:36<00:08, 11.49it/s]
# Right points r1 and r2, (529, 320) (890, 539)
# Left points l1 and l2, (472, 320) (169, 539)
# Right points r1 and r2, (529, 320) (890, 539)
# Left points l1 and l2, (472, 320) (104, 539)
# Right points r1 and r2, (530, 320) (889, 538)
# Left points l1 and l2, (472, 320) (168, 539)
# Right points r1 and r2, (508, 320) (638, 400)
# Left points l1 and l2, (474, 320) (169, 539)
#  87%|████████▋ | 594/682 [00:37<00:06, 14.06it/s]
# Right points r1 and r2, (506, 320) (756, 462)
# Left points l1 and l2, (474, 320) (170, 539)
# Right points r1 and r2, (503, 321) (799, 490)
# Left points l1 and l2, (474, 321) (170, 539)
# Right points r1 and r2, (502, 321) (856, 523)
# Left points l1 and l2, (474, 321) (172, 539)
# Right points r1 and r2, (495, 320) (709, 444)
# Left points l1 and l2, (473, 320) (174, 538)
#  87%|████████▋ | 596/682 [00:37<00:06, 13.43it/s]
# Right points r1 and r2, (495, 320) (739, 461)
# Left points l1 and l2, (472, 320) (176, 538)
# Right points r1 and r2, (501, 321) (776, 481)
# Left points l1 and l2, (473, 321) (181, 538)
#  88%|████████▊ | 600/682 [00:37<00:08, 10.18it/s]
# Right points r1 and r2, (503, 320) (825, 509)
# Left points l1 and l2, (473, 320) (175, 538)
# Right points r1 and r2, (505, 320) (883, 539)
# Left points l1 and l2, (473, 320) (176, 538)
# Right points r1 and r2, (506, 320) (883, 539)
# Left points l1 and l2, (472, 320) (176, 539)
#  89%|████████▊ | 604/682 [00:38<00:05, 13.10it/s]
# Right points r1 and r2, (508, 320) (885, 539)
# Left points l1 and l2, (471, 320) (176, 539)
# Right points r1 and r2, (529, 320) (879, 538)
# Left points l1 and l2, (470, 320) (177, 537)
# Right points r1 and r2, (533, 320) (881, 532)
# Left points l1 and l2, (470, 320) (173, 539)
# Right points r1 and r2, (553, 320) (649, 403)
# Left points l1 and l2, (470, 320) (173, 539)
#  89%|████████▉ | 607/682 [00:38<00:05, 14.96it/s]
# Right points r1 and r2, (557, 320) (784, 478)
# Left points l1 and l2, (471, 320) (173, 538)
# Right points r1 and r2, (522, 321) (835, 508)
# Left points l1 and l2, (471, 321) (175, 539)
# Right points r1 and r2, (508, 320) (702, 435)
# Left points l1 and l2, (471, 320) (185, 534)
# Right points r1 and r2, (510, 320) (729, 450)
# Left points l1 and l2, (468, 320) (177, 539)
#  89%|████████▉ | 609/682 [00:38<00:05, 13.52it/s]
# Right points r1 and r2, (514, 320) (762, 469)
# Left points l1 and l2, (471, 320) (190, 538)
# Right points r1 and r2, (514, 320) (806, 493)
# Left points l1 and l2, (471, 320) (178, 539)
#  90%|████████▉ | 613/682 [00:38<00:04, 13.87it/s]
# Right points r1 and r2, (515, 320) (866, 526)
# Left points l1 and l2, (467, 320) (180, 539)
# Right points r1 and r2, (514, 320) (891, 538)
# Left points l1 and l2, (470, 320) (180, 539)
# Right points r1 and r2, (512, 320) (891, 539)
# Left points l1 and l2, (464, 320) (181, 539)
# Right points r1 and r2, (513, 320) (891, 539)
# Left points l1 and l2, (470, 320) (182, 538)
#  91%|█████████ | 619/682 [00:38<00:03, 17.30it/s]
# Right points r1 and r2, (512, 320) (633, 396)
# Left points l1 and l2, (470, 320) (182, 539)
# Right points r1 and r2, (514, 321) (642, 402)
# Left points l1 and l2, (469, 321) (201, 539)
# Right points r1 and r2, (517, 320) (658, 410)
# Left points l1 and l2, (468, 320) (181, 539)
# Right points r1 and r2, (510, 320) (811, 492)
# Left points l1 and l2, (469, 320) (183, 538)
# Right points r1 and r2, (523, 320) (873, 527)
# Left points l1 and l2, (469, 320) (185, 539)
#  91%|█████████ | 621/682 [00:39<00:03, 15.40it/s]
# Right points r1 and r2, (512, 321) (720, 444)
# Left points l1 and l2, (468, 321) (186, 539)
# Right points r1 and r2, (516, 321) (750, 461)
# Left points l1 and l2, (468, 321) (187, 539)
# Right points r1 and r2, (518, 320) (790, 482)
# Left points l1 and l2, (465, 320) (193, 538)
#  92%|█████████▏| 626/682 [00:39<00:03, 16.76it/s]
# Right points r1 and r2, (538, 321) (843, 510)
# Left points l1 and l2, (464, 321) (198, 538)
# Right points r1 and r2, (540, 320) (902, 539)
# Left points l1 and l2, (466, 320) (183, 538)
# Right points r1 and r2, (542, 320) (892, 539)
# Left points l1 and l2, (466, 320) (183, 538)
# Right points r1 and r2, (547, 320) (902, 538)
# Left points l1 and l2, (466, 320) (182, 538)
# Right points r1 and r2, (525, 321) (901, 539)
# Left points l1 and l2, (460, 321) (184, 538)
#  93%|█████████▎| 631/682 [00:39<00:03, 16.72it/s]
# Right points r1 and r2, (527, 320) (640, 398)
# Left points l1 and l2, (463, 320) (185, 539)
# Right points r1 and r2, (527, 320) (653, 405)
# Left points l1 and l2, (467, 320) (124, 539)
# Right points r1 and r2, (516, 320) (796, 481)
# Left points l1 and l2, (467, 320) (73, 538)
# Right points r1 and r2, (514, 321) (850, 509)
# Left points l1 and l2, (467, 321) (37, 539)
#  93%|█████████▎| 635/682 [00:39<00:02, 15.93it/s]
# Right points r1 and r2, (515, 321) (709, 438)
# Left points l1 and l2, (467, 321) (192, 538)
# Right points r1 and r2, (517, 320) (738, 453)
# Left points l1 and l2, (466, 320) (188, 539)
# Right points r1 and r2, (516, 320) (773, 472)
# Left points l1 and l2, (466, 320) (186, 539)
# Right points r1 and r2, (518, 320) (821, 497)
# Left points l1 and l2, (465, 320) (184, 539)
#  93%|█████████▎| 637/682 [00:39<00:02, 16.84it/s]
# Right points r1 and r2, (524, 320) (883, 532)
# Left points l1 and l2, (465, 320) (183, 539)
# Right points r1 and r2, (521, 320) (898, 539)
# Left points l1 and l2, (465, 320) (181, 539)
# Right points r1 and r2, (522, 320) (896, 539)
# Left points l1 and l2, (464, 320) (179, 539)
#  94%|█████████▎| 639/682 [00:40<00:02, 15.19it/s]
# Right points r1 and r2, (514, 320) (895, 539)
# Left points l1 and l2, (464, 320) (179, 539)
# Right points r1 and r2, (514, 321) (629, 396)
# Left points l1 and l2, (464, 321) (179, 539)
# Right points r1 and r2, (508, 321) (736, 451)
# Left points l1 and l2, (464, 321) (177, 539)
#  94%|█████████▍| 643/682 [00:40<00:02, 14.19it/s]
# Right points r1 and r2, (514, 320) (656, 411)
# Left points l1 and l2, (464, 320) (175, 538)
# Right points r1 and r2, (516, 320) (818, 498)
# Left points l1 and l2, (464, 320) (174, 539)
# Right points r1 and r2, (528, 320) (885, 536)
# Left points l1 and l2, (463, 320) (184, 539)
# Right points r1 and r2, (518, 320) (718, 445)
# Left points l1 and l2, (463, 320) (173, 539)
#  95%|█████████▌| 648/682 [00:40<00:02, 14.21it/s]
# Right points r1 and r2, (517, 320) (749, 464)
# Left points l1 and l2, (463, 320) (173, 538)
# Right points r1 and r2, (510, 320) (792, 488)
# Left points l1 and l2, (463, 320) (173, 539)
# Right points r1 and r2, (519, 320) (847, 520)
# Left points l1 and l2, (463, 320) (174, 539)
#  95%|█████████▌| 650/682 [00:40<00:02, 15.20it/s]
# Right points r1 and r2, (506, 321) (883, 539)
# Left points l1 and l2, (462, 321) (173, 538)
# Right points r1 and r2, (521, 320) (883, 539)
# Left points l1 and l2, (462, 320) (173, 539)
# Right points r1 and r2, (522, 321) (883, 539)
# Left points l1 and l2, (462, 321) (171, 538)
#  96%|█████████▌| 652/682 [00:41<00:02, 10.37it/s]
# Right points r1 and r2, (514, 322) (881, 538)
# Left points l1 and l2, (460, 322) (170, 539)
# Right points r1 and r2, (524, 320) (632, 398)
# Left points l1 and l2, (462, 320) (167, 539)
#  96%|█████████▌| 654/682 [00:41<00:03,  8.51it/s]
# Right points r1 and r2, (525, 320) (748, 461)
# Left points l1 and l2, (461, 320) (164, 539)
# Right points r1 and r2, (527, 320) (789, 487)
# Left points l1 and l2, (461, 320) (163, 539)
#  96%|█████████▋| 658/682 [00:41<00:02,  9.60it/s]
# Right points r1 and r2, (528, 321) (845, 519)
# Left points l1 and l2, (461, 321) (163, 539)
# Right points r1 and r2, (529, 320) (701, 439)
# Left points l1 and l2, (461, 320) (171, 538)
# Right points r1 and r2, (531, 320) (730, 455)
# Left points l1 and l2, (461, 320) (160, 539)
# Right points r1 and r2, (532, 321) (765, 476)
# Left points l1 and l2, (461, 321) (159, 539)
#  97%|█████████▋| 664/682 [00:42<00:01, 13.39it/s]
# Right points r1 and r2, (520, 320) (815, 505)
# Left points l1 and l2, (460, 320) (159, 539)
# Right points r1 and r2, (510, 321) (875, 539)
# Left points l1 and l2, (461, 321) (159, 539)
# Right points r1 and r2, (506, 320) (874, 539)
# Left points l1 and l2, (460, 320) (158, 539)
# Right points r1 and r2, (523, 320) (874, 539)
# Left points l1 and l2, (459, 320) (157, 539)
# Right points r1 and r2, (525, 320) (876, 539)
# Left points l1 and l2, (460, 320) (155, 539)
#  98%|█████████▊| 667/682 [00:42<00:00, 15.23it/s]
# Right points r1 and r2, (544, 321) (626, 393)
# Left points l1 and l2, (460, 321) (153, 539)
# Right points r1 and r2, (546, 320) (638, 400)
# Left points l1 and l2, (460, 320) (156, 539)
# Right points r1 and r2, (549, 320) (769, 472)
# Left points l1 and l2, (460, 320) (151, 539)
# Right points r1 and r2, (529, 320) (669, 419)
# Left points l1 and l2, (460, 320) (150, 538)
# Right points r1 and r2, (530, 325) (690, 432)
# Left points l1 and l2, (457, 325) (150, 538)
#  99%|█████████▊| 673/682 [00:42<00:00, 17.48it/s]
# Right points r1 and r2, (520, 321) (716, 447)
# Left points l1 and l2, (459, 321) (150, 539)
# Right points r1 and r2, (533, 321) (839, 533)
# Left points l1 and l2, (459, 321) (150, 538)
# Right points r1 and r2, (510, 323) (792, 492)
# Left points l1 and l2, (459, 323) (150, 538)
# Right points r1 and r2, (506, 324) (851, 527)
# Left points l1 and l2, (459, 324) (151, 539)
#  99%|█████████▉| 675/682 [00:42<00:00, 13.68it/s]
# Right points r1 and r2, (506, 322) (873, 538)
# Left points l1 and l2, (458, 322) (152, 538)
# Right points r1 and r2, (492, 322) (871, 538)
# Left points l1 and l2, (458, 322) (152, 538)
# Right points r1 and r2, (498, 324) (892, 538)
# Left points l1 and l2, (458, 324) (152, 539)
# 100%|█████████▉| 681/682 [00:43<00:00, 16.93it/s]
# Right points r1 and r2, (506, 325) (623, 395)
# Left points l1 and l2, (457, 325) (152, 538)
# Right points r1 and r2, (499, 324) (635, 402)
# Left points l1 and l2, (457, 324) (157, 538)
# Right points r1 and r2, (495, 322) (648, 410)
# Left points l1 and l2, (457, 322) (156, 539)
# Right points r1 and r2, (493, 323) (801, 495)
# Left points l1 and l2, (456, 323) (159, 539)
# Right points r1 and r2, (492, 322) (862, 536)
# Left points l1 and l2, (456, 322) (158, 539)
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: yellow.mp4
#
# CPU times: user 27.3 s, sys: 2.86 s, total: 30.1 s
# Wall time: 44.7 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="yellow.mp4">
# </video>

# %% [markdown]
# ## Reflections
#
# Congratulations on finding the lane lines!  As the final step in this project, we would like you to share your thoughts on your lane finding pipeline... specifically, how could you imagine making your algorithm better / more robust?  Where will your current algorithm be likely to fail?
#
# Please add your thoughts below,  and if you're up for making your pipeline more robust, be sure to scroll down and check out the optional challenge video below!
#
#
# ## Reflections on Finding Lane Lines
#
#
# This project was such a fantastic (and frustrating) learning experience.
#
# I spend a majority of my time at the beginning of the project looking through the forums to get ideas on how other students were approaching the problem.
#
# These are the three approaches I took towards drawing the lanes.
#
#
#
#
# There are a couple of algorithms to decide how to draw the lines.
#
#
# ### Approach 1 - Extremum
#
# The first approach was to simply collect all the points in the lane, find the topmost left and rightmost points and graph lines between them. This worked somewhat well but it lacked the ability to "fill in" where there was an absence of lane markings.
#
# ```python
#     # Line Extremum Approach
#     right_lines = np.array(list(filter(lambda x: x[0] > (img.shape[1]/2), lines)))
#     max_right_x, max_right_y = right_lines.max(axis=0)
#     min_right_x, min_right_y = right_lines.min(axis=0)
# ```
#
#
#
# ### Approach 2 - Average Slope
#
# Another, more robust way that should work theorhetically would be to predict the x coordinates based on the average slope and solving for it with the average slope and average y and y intercept.
#
# ```python
#     # Average slope Approach
#     avg_right_slope = right_slopes.mean()
#
#     # average point
#     avg_right_point = np.mean(right_lines, axis=0)
#
#     # y intercept of right line
#     # b = y - mx
#     right_y_intercept = avg_right_point[1] - avg_right_slope * avg_right_point[0]
#
#     # Calculate x values based on average slope and y intercept
#     max_right_x = int((min_right_y - right_y_intercept)/avg_right_slope)
#     min_right_x = int((max_right_y - right_y_intercept)/avg_right_slope)
#
#     r1 = (min_right_x, min_right_y)
#     r2 = (max_right_x, img.shape[0]) # ground to bottom of image
# ```
#
# This however would get thrown off by outliers returned by the Hough transform.
#
#
# ### Approach 3 - Curve fitting
#
# This felt like the most robust way to connect the dots by using numpy to generate a polynomial curve that modeled each lane, and the one that I'm using in my submission. I'm definitely the most happy with the results for this one becuase it allows us to generate sensible x values to complete the lanes when there are dashed lines in the road.
#
# ```python
#     # Curve fitting approach
#     # calculate polynomial fit for the points in right lane
#     right_curve = np.poly1d(np.polyfit(right_lines[:,1], right_lines[:,0], 2))
#     left_curve  = np.poly1d(np.polyfit(left_lines[:,1], left_lines[:,0], 2))
#
#     # use new curve function f(y) to calculate x values
#     max_right_x = int(right_curve(img.shape[0]))
#     min_left_x = int(left_curve(img.shape[0]))
# ```
#
# And with that our outputs are pretty good!
#
#
# I certainly appreciated the opportunity to learn and work with Numpy and openCV. It was a fantastic set of tools to work with and I'm really happy to have built a moderately successful result.
#
# Thank you to the mentors as well as the office hour instructors.

# %% [markdown]
# ## Submission
#
# If you're satisfied with your video outputs it's time to submit!  Submit this ipython notebook for review.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'extra.mp4'
clip2 = VideoFileClip('challenge.mp4')
challenge_clip = clip2.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)
# Out:
# Right points r1 and r2, (641, 360) (1202, 713)
# Left points l1 and l2, (639, 360) (178, 700)
# [MoviePy] >>>> Building video extra.mp4
# [MoviePy] Writing video extra.mp4
#   0%|          | 0/251 [00:00<?, ?it/s]
# Right points r1 and r2, (641, 360) (1202, 713)
# Left points l1 and l2, (639, 360) (178, 700)
# Right points r1 and r2, (642, 360) (1157, 716)
# Left points l1 and l2, (638, 360) (167, 700)
#   1%|          | 2/251 [00:00<00:24, 10.13it/s]
# Right points r1 and r2, (641, 360) (1153, 708)
# Left points l1 and l2, (639, 360) (166, 686)
# Right points r1 and r2, (641, 361) (1168, 695)
# Left points l1 and l2, (636, 361) (167, 686)
#   2%|▏         | 4/251 [00:00<00:23, 10.35it/s]
# Right points r1 and r2, (641, 362) (1257, 717)
# Left points l1 and l2, (638, 362) (167, 686)
#   2%|▏         | 5/251 [00:00<00:24, 10.19it/s]
# Right points r1 and r2, (641, 362) (1255, 718)
# Left points l1 and l2, (637, 362) (189, 700)
#   2%|▏         | 6/251 [00:00<00:24, 10.12it/s]
# Right points r1 and r2, (642, 361) (1170, 702)
# Left points l1 and l2, (638, 361) (189, 699)
#   3%|▎         | 7/251 [00:00<00:24, 10.04it/s]
# Right points r1 and r2, (641, 361) (1147, 704)
# Left points l1 and l2, (638, 361) (173, 700)
#   4%|▎         | 9/251 [00:00<00:22, 10.56it/s]
# Right points r1 and r2, (641, 361) (1170, 677)
# Left points l1 and l2, (639, 361) (185, 700)
# Right points r1 and r2, (641, 362) (1124, 677)
# Left points l1 and l2, (639, 362) (181, 700)
#   4%|▍         | 11/251 [00:01<00:23, 10.10it/s]
# Right points r1 and r2, (642, 362) (1127, 705)
# Left points l1 and l2, (638, 362) (182, 700)
#   5%|▍         | 12/251 [00:01<00:25,  9.38it/s]
# Right points r1 and r2, (641, 362) (1137, 709)
# Left points l1 and l2, (639, 362) (176, 700)
# Right points r1 and r2, (642, 361) (1171, 718)
# Left points l1 and l2, (637, 361) (111, 700)
# Right points r1 and r2, (642, 361) (1171, 695)
# Left points l1 and l2, (639, 361) (172, 700)
#   6%|▌         | 14/251 [00:01<00:24,  9.71it/s]
# Right points r1 and r2, (642, 360) (1156, 704)
# Left points l1 and l2, (639, 360) (181, 700)
#   7%|▋         | 17/251 [00:01<00:23, 10.13it/s]
# Right points r1 and r2, (641, 360) (1128, 706)
# Left points l1 and l2, (637, 360) (185, 700)
# Right points r1 and r2, (643, 360) (1170, 706)
# Left points l1 and l2, (639, 360) (177, 685)
# Right points r1 and r2, (644, 361) (1169, 706)
# Left points l1 and l2, (637, 361) (177, 699)
#   8%|▊         | 19/251 [00:01<00:21, 10.57it/s]
# Right points r1 and r2, (642, 360) (1161, 695)
# Left points l1 and l2, (639, 360) (181, 700)
# Right points r1 and r2, (641, 362) (1161, 717)
# Left points l1 and l2, (637, 362) (179, 700)
# Right points r1 and r2, (643, 361) (1152, 677)
# Left points l1 and l2, (638, 361) (180, 700)
#   8%|▊         | 21/251 [00:02<00:22, 10.31it/s]
# Right points r1 and r2, (641, 361) (1165, 676)
# Left points l1 and l2, (639, 361) (190, 685)
#   9%|▉         | 23/251 [00:02<00:23,  9.52it/s]
# Right points r1 and r2, (642, 362) (1151, 704)
# Left points l1 and l2, (638, 362) (190, 700)
#  10%|▉         | 24/251 [00:02<00:23,  9.52it/s]
# Right points r1 and r2, (641, 349) (1159, 710)
# Left points l1 and l2, (638, 349) (177, 699)
#  10%|▉         | 25/251 [00:02<00:23,  9.42it/s]
# Right points r1 and r2, (643, 348) (1166, 703)
# Left points l1 and l2, (638, 348) (191, 699)
#  10%|█         | 26/251 [00:02<00:26,  8.54it/s]
# Right points r1 and r2, (641, 348) (1168, 716)
# Left points l1 and l2, (639, 348) (194, 700)
# Right points r1 and r2, (641, 351) (1169, 703)
# Left points l1 and l2, (638, 351) (197, 699)
# Right points r1 and r2, (641, 345) (1168, 704)
# Left points l1 and l2, (639, 345) (201, 700)
#  12%|█▏        | 29/251 [00:02<00:23,  9.35it/s]
# Right points r1 and r2, (641, 345) (1141, 716)
# Left points l1 and l2, (638, 345) (183, 699)
#  12%|█▏        | 30/251 [00:03<00:23,  9.42it/s]
# Right points r1 and r2, (641, 361) (1257, 718)
# Left points l1 and l2, (638, 361) (157, 700)
#  12%|█▏        | 31/251 [00:03<00:24,  8.83it/s]
# Right points r1 and r2, (641, 340) (1257, 717)
# Left points l1 and l2, (639, 340) (197, 685)
#  13%|█▎        | 32/251 [00:03<00:25,  8.48it/s]
# Right points r1 and r2, (641, 336) (1199, 714)
# Left points l1 and l2, (639, 336) (182, 699)
#  13%|█▎        | 33/251 [00:03<00:26,  8.19it/s]
# Right points r1 and r2, (642, 336) (1169, 716)
# Left points l1 and l2, (639, 336) (177, 700)
#  14%|█▎        | 34/251 [00:03<00:26,  8.21it/s]
# Right points r1 and r2, (641, 334) (1159, 716)
# Left points l1 and l2, (639, 334) (174, 700)
# Right points r1 and r2, (641, 333) (1257, 717)
# Left points l1 and l2, (639, 333) (191, 703)
# Right points r1 and r2, (641, 321) (1258, 717)
# Left points l1 and l2, (639, 321) (204, 700)
#  14%|█▍        | 36/251 [00:03<00:24,  8.74it/s]
# Right points r1 and r2, (641, 326) (1158, 718)
#  15%|█▌        | 38/251 [00:03<00:22,  9.34it/s]
# Left points l1 and l2, (637, 326) (179, 700)
# Right points r1 and r2, (643, 335) (1166, 718)
# Left points l1 and l2, (639, 335) (178, 700)
#  16%|█▌        | 39/251 [00:04<00:26,  8.01it/s]
# Right points r1 and r2, (644, 320) (1171, 717)
# Left points l1 and l2, (638, 320) (190, 700)
#  17%|█▋        | 42/251 [00:04<00:29,  7.14it/s]
# Right points r1 and r2, (643, 332) (1162, 717)
# Left points l1 and l2, (639, 332) (176, 700)
# Right points r1 and r2, (641, 320) (1160, 704)
# Left points l1 and l2, (639, 320) (194, 700)
# Right points r1 and r2, (645, 321) (1171, 718)
# Left points l1 and l2, (639, 321) (178, 686)
#  18%|█▊        | 44/251 [00:04<00:26,  7.85it/s]
# Right points r1 and r2, (641, 321) (1254, 718)
# Left points l1 and l2, (638, 321) (195, 700)
# Right points r1 and r2, (642, 320) (1171, 714)
# Left points l1 and l2, (638, 320) (170, 700)
#  18%|█▊        | 45/251 [00:05<00:36,  5.66it/s]
# Right points r1 and r2, (641, 320) (1257, 717)
# Left points l1 and l2, (639, 320) (145, 700)
#  19%|█▊        | 47/251 [00:05<00:36,  5.58it/s]
# Right points r1 and r2, (642, 320) (1257, 718)
# Left points l1 and l2, (639, 320) (177, 686)
# Right points r1 and r2, (641, 320) (1166, 719)
# Left points l1 and l2, (639, 320) (188, 700)
#  20%|█▉        | 49/251 [00:05<00:35,  5.64it/s]
# Right points r1 and r2, (641, 320) (1166, 710)
# Left points l1 and l2, (639, 320) (191, 700)
# Right points r1 and r2, (641, 320) (1257, 717)
# Left points l1 and l2, (639, 320) (183, 700)
#  20%|█▉        | 50/251 [00:05<00:31,  6.42it/s]
# Right points r1 and r2, (641, 320) (1173, 718)
# Left points l1 and l2, (638, 320) (183, 700)
# Right points r1 and r2, (641, 320) (1256, 718)
# Left points l1 and l2, (639, 320) (178, 700)
# Right points r1 and r2, (642, 320) (1161, 713)
# Left points l1 and l2, (638, 320) (167, 699)
#  21%|██        | 53/251 [00:06<00:25,  7.63it/s]
# Right points r1 and r2, (642, 320) (1256, 718)
# Left points l1 and l2, (638, 320) (175, 700)
# Right points r1 and r2, (642, 320) (1257, 717)
# Left points l1 and l2, (639, 320) (178, 699)
#  22%|██▏       | 56/251 [00:06<00:29,  6.72it/s]
# Right points r1 and r2, (641, 320) (1173, 706)
# Left points l1 and l2, (639, 320) (183, 699)
# Right points r1 and r2, (649, 320) (1257, 717)
# Left points l1 and l2, (637, 320) (181, 700)
#  23%|██▎       | 58/251 [00:06<00:25,  7.46it/s]
# Right points r1 and r2, (641, 320) (1171, 719)
# Left points l1 and l2, (639, 320) (182, 699)
# Right points r1 and r2, (642, 320) (1257, 718)
# Left points l1 and l2, (639, 320) (185, 703)
#  24%|██▍       | 60/251 [00:07<00:23,  8.04it/s]
# Right points r1 and r2, (641, 320) (1171, 718)
# Left points l1 and l2, (638, 320) (180, 700)
# Right points r1 and r2, (643, 320) (1257, 719)
# Left points l1 and l2, (639, 320) (187, 700)
#  25%|██▍       | 62/251 [00:07<00:23,  8.20it/s]
# Right points r1 and r2, (641, 320) (1257, 718)
# Left points l1 and l2, (639, 320) (185, 704)
# Right points r1 and r2, (642, 321) (1171, 718)
# Left points l1 and l2, (639, 321) (181, 699)
# Right points r1 and r2, (641, 320) (1171, 677)
# Left points l1 and l2, (639, 320) (190, 700)
#  26%|██▌       | 65/251 [00:07<00:22,  8.21it/s]
# Right points r1 and r2, (641, 320) (1140, 719)
# Left points l1 and l2, (639, 320) (197, 699)
# Right points r1 and r2, (641, 320) (1171, 677)
# Left points l1 and l2, (639, 320) (182, 699)
#  26%|██▋       | 66/251 [00:07<00:21,  8.59it/s]
# Right points r1 and r2, (641, 320) (1257, 717)
# Left points l1 and l2, (639, 320) (183, 700)
# Right points r1 and r2, (641, 320) (1257, 716)
# Left points l1 and l2, (639, 320) (180, 700)
#  27%|██▋       | 69/251 [00:08<00:24,  7.57it/s]
# Right points r1 and r2, (641, 320) (1245, 718)
# Left points l1 and l2, (638, 320) (182, 686)
# Right points r1 and r2, (641, 322) (1171, 719)
# Left points l1 and l2, (639, 322) (184, 699)
#  28%|██▊       | 70/251 [00:08<00:24,  7.46it/s]
# Right points r1 and r2, (641, 320) (1276, 717)
# Left points l1 and l2, (639, 320) (198, 699)
# Right points r1 and r2, (647, 320) (1166, 719)
# Left points l1 and l2, (639, 320) (192, 700)
#  29%|██▉       | 73/251 [00:08<00:22,  8.07it/s]
# Right points r1 and r2, (643, 320) (1171, 717)
# Left points l1 and l2, (638, 320) (181, 699)
# Right points r1 and r2, (642, 322) (1257, 717)
# Left points l1 and l2, (639, 322) (182, 700)
#  29%|██▉       | 74/251 [00:08<00:20,  8.45it/s]
# Right points r1 and r2, (641, 320) (1257, 719)
# Left points l1 and l2, (635, 320) (186, 700)
# Right points r1 and r2, (642, 320) (1168, 704)
# Left points l1 and l2, (639, 320) (194, 699)
#  31%|███       | 77/251 [00:09<00:20,  8.48it/s]
# Right points r1 and r2, (644, 322) (1169, 704)
# Left points l1 and l2, (634, 322) (192, 700)
# Right points r1 and r2, (642, 320) (1191, 677)
# Left points l1 and l2, (638, 320) (196, 699)
#  31%|███       | 78/251 [00:09<00:20,  8.55it/s]
# Right points r1 and r2, (642, 320) (1257, 717)
# Left points l1 and l2, (635, 320) (193, 700)
# Right points r1 and r2, (641, 326) (1278, 718)
# Left points l1 and l2, (635, 326) (199, 700)
#  32%|███▏      | 81/251 [00:09<00:22,  7.47it/s]
# Right points r1 and r2, (641, 322) (1183, 703)
# Left points l1 and l2, (639, 322) (176, 686)
# Right points r1 and r2, (641, 321) (1258, 717)
# Left points l1 and l2, (638, 321) (184, 703)
#  33%|███▎      | 83/251 [00:10<00:20,  8.10it/s]
# Right points r1 and r2, (642, 320) (1257, 716)
# Left points l1 and l2, (639, 320) (185, 700)
# Right points r1 and r2, (642, 320) (1187, 705)
# Left points l1 and l2, (639, 320) (190, 700)
#  34%|███▍      | 85/251 [00:10<00:24,  6.78it/s]
# Right points r1 and r2, (642, 320) (1254, 718)
# Left points l1 and l2, (639, 320) (180, 699)
# Right points r1 and r2, (645, 320) (1257, 718)
# Left points l1 and l2, (637, 320) (176, 699)
#  35%|███▍      | 87/251 [00:10<00:22,  7.37it/s]
# Right points r1 and r2, (645, 328) (1276, 718)
# Left points l1 and l2, (636, 328) (190, 700)
# Right points r1 and r2, (641, 320) (1186, 703)
# Left points l1 and l2, (639, 320) (155, 699)
#  35%|███▌      | 88/251 [00:10<00:30,  5.41it/s]
# Right points r1 and r2, (641, 323) (1181, 703)
# Left points l1 and l2, (635, 323) (142, 699)
#  36%|███▌      | 90/251 [00:11<00:29,  5.46it/s]
# Right points r1 and r2, (646, 324) (1171, 703)
# Left points l1 and l2, (639, 324) (108, 699)
# Right points r1 and r2, (641, 338) (1179, 704)
# Left points l1 and l2, (635, 338) (75, 699)
#  37%|███▋      | 92/251 [00:11<00:24,  6.53it/s]
# Right points r1 and r2, (642, 335) (1254, 718)
# Left points l1 and l2, (638, 335) (82, 702)
# Right points r1 and r2, (641, 332) (1257, 717)
# Left points l1 and l2, (639, 332) (55, 710)
#  37%|███▋      | 94/251 [00:11<00:22,  6.87it/s]
# Right points r1 and r2, (641, 337) (1257, 717)
# Left points l1 and l2, (639, 337) (97, 685)
# Right points r1 and r2, (641, 340) (1183, 677)
# Left points l1 and l2, (637, 340) (55, 686)
#  38%|███▊      | 95/251 [00:11<00:23,  6.51it/s]
# Right points r1 and r2, (642, 340) (1249, 717)
# Left points l1 and l2, (639, 340) (54, 699)
#  39%|███▊      | 97/251 [00:12<00:24,  6.16it/s]
# Right points r1 and r2, (641, 343) (1257, 717)
# Left points l1 and l2, (639, 343) (78, 711)
# Right points r1 and r2, (641, 350) (1180, 703)
# Left points l1 and l2, (639, 350) (65, 699)
#  39%|███▉      | 99/251 [00:12<00:20,  7.27it/s]
# Right points r1 and r2, (641, 349) (1187, 704)
# Left points l1 and l2, (636, 349) (53, 700)
# Right points r1 and r2, (641, 357) (1196, 677)
# Left points l1 and l2, (638, 357) (57, 697)
#  40%|███▉      | 100/251 [00:12<00:20,  7.27it/s]
# Right points r1 and r2, (645, 323) (1170, 677)
# Left points l1 and l2, (639, 323) (65, 685)
#  40%|████      | 101/251 [00:12<00:26,  5.75it/s]
# Right points r1 and r2, (641, 358) (1278, 719)
# Left points l1 and l2, (639, 358) (57, 701)
#  41%|████      | 103/251 [00:13<00:23,  6.36it/s]
# Right points r1 and r2, (641, 325) (1254, 717)
# Left points l1 and l2, (639, 325) (91, 708)
# Right points r1 and r2, (641, 338) (1198, 703)
# Left points l1 and l2, (639, 338) (87, 700)
#  41%|████▏     | 104/251 [00:13<00:22,  6.64it/s]
# Right points r1 and r2, (644, 332) (1190, 692)
# Left points l1 and l2, (639, 332) (110, 689)
# Right points r1 and r2, (642, 331) (1188, 703)
# Left points l1 and l2, (635, 331) (98, 684)
#  43%|████▎     | 107/251 [00:13<00:21,  6.66it/s]
# Right points r1 and r2, (641, 330) (1198, 715)
# Left points l1 and l2, (637, 330) (54, 718)
# Right points r1 and r2, (641, 326) (1181, 692)
# Left points l1 and l2, (634, 326) (76, 699)
#  43%|████▎     | 109/251 [00:14<00:26,  5.46it/s]
# Right points r1 and r2, (641, 321) (1196, 704)
# Left points l1 and l2, (639, 321) (54, 715)
# Right points r1 and r2, (641, 324) (1186, 703)
# Left points l1 and l2, (638, 324) (85, 714)
#  44%|████▍     | 111/251 [00:14<00:20,  6.83it/s]
# Right points r1 and r2, (641, 321) (1179, 703)
# Left points l1 and l2, (637, 321) (54, 699)
# Right points r1 and r2, (645, 324) (1192, 696)
# Left points l1 and l2, (638, 324) (74, 700)
#  45%|████▌     | 113/251 [00:14<00:17,  7.84it/s]
# Right points r1 and r2, (642, 320) (1187, 692)
# Left points l1 and l2, (639, 320) (61, 699)
# Right points r1 and r2, (641, 340) (1191, 703)
# Left points l1 and l2, (639, 340) (64, 699)
# Right points r1 and r2, (644, 320) (1189, 692)
# Left points l1 and l2, (639, 320) (55, 685)
# Right points r1 and r2, (642, 322) (1189, 691)
# Left points l1 and l2, (639, 322) (63, 718)
#  46%|████▌     | 116/251 [00:15<00:19,  6.92it/s]
# Right points r1 and r2, (641, 322) (1195, 679)
# Left points l1 and l2, (639, 322) (53, 717)
# Right points r1 and r2, (641, 327) (1185, 676)
# Left points l1 and l2, (637, 327) (69, 713)
# Right points r1 and r2, (641, 320) (1185, 677)
# Left points l1 and l2, (639, 320) (53, 700)
#  48%|████▊     | 120/251 [00:15<00:17,  7.57it/s]
# Right points r1 and r2, (641, 320) (1186, 677)
# Left points l1 and l2, (639, 320) (64, 700)
# Right points r1 and r2, (641, 321) (1187, 715)
# Left points l1 and l2, (637, 321) (59, 711)
#  49%|████▊     | 122/251 [00:15<00:15,  8.25it/s]
# Right points r1 and r2, (641, 320) (1198, 704)
# Left points l1 and l2, (639, 320) (60, 699)
# Right points r1 and r2, (642, 334) (1187, 702)
# Left points l1 and l2, (639, 334) (55, 698)
#  49%|████▉     | 124/251 [00:16<00:14,  8.63it/s]
# Right points r1 and r2, (642, 329) (1191, 703)
# Left points l1 and l2, (639, 329) (55, 699)
# Right points r1 and r2, (641, 329) (1187, 706)
# Left points l1 and l2, (638, 329) (53, 708)
#  50%|█████     | 126/251 [00:16<00:15,  8.27it/s]
# Right points r1 and r2, (643, 325) (1189, 703)
# Left points l1 and l2, (639, 325) (58, 699)
# Right points r1 and r2, (646, 322) (1189, 703)
# Left points l1 and l2, (636, 322) (53, 718)
#  51%|█████     | 128/251 [00:16<00:14,  8.40it/s]
# Right points r1 and r2, (642, 320) (1189, 692)
# Left points l1 and l2, (639, 320) (63, 710)
# Right points r1 and r2, (641, 321) (1188, 677)
# Left points l1 and l2, (636, 321) (54, 686)
#  51%|█████▏    | 129/251 [00:16<00:15,  7.84it/s]
# Right points r1 and r2, (646, 320) (1191, 678)
# Left points l1 and l2, (636, 320) (99, 687)
# Right points r1 and r2, (642, 320) (1187, 676)
# Left points l1 and l2, (638, 320) (63, 711)
#  53%|█████▎    | 132/251 [00:17<00:17,  6.66it/s]
# Right points r1 and r2, (644, 321) (1191, 677)
# Left points l1 and l2, (637, 321) (64, 707)
# Right points r1 and r2, (647, 320) (1170, 677)
# Left points l1 and l2, (637, 320) (53, 706)
#  53%|█████▎    | 134/251 [00:17<00:17,  6.88it/s]
# Right points r1 and r2, (645, 322) (1188, 677)
# Left points l1 and l2, (635, 322) (55, 699)
# Right points r1 and r2, (643, 320) (1191, 692)
# Left points l1 and l2, (636, 320) (54, 686)
#  54%|█████▍    | 136/251 [00:17<00:14,  7.85it/s]
# Right points r1 and r2, (641, 320) (1189, 692)
# Left points l1 and l2, (632, 320) (54, 717)
# Right points r1 and r2, (643, 321) (1153, 695)
# Left points l1 and l2, (639, 321) (69, 718)
#  55%|█████▍    | 138/251 [00:18<00:14,  7.85it/s]
# Right points r1 and r2, (642, 320) (1189, 694)
# Left points l1 and l2, (638, 320) (55, 708)
# Right points r1 and r2, (641, 320) (1192, 693)
# Left points l1 and l2, (638, 320) (77, 701)
#  56%|█████▌    | 140/251 [00:18<00:13,  8.35it/s]
# Right points r1 and r2, (641, 320) (1173, 675)
# Left points l1 and l2, (639, 320) (53, 688)
# Right points r1 and r2, (641, 320) (1191, 677)
# Left points l1 and l2, (637, 320) (73, 687)
#  57%|█████▋    | 142/251 [00:18<00:12,  8.85it/s]
# Right points r1 and r2, (644, 320) (1192, 678)
# Left points l1 and l2, (638, 320) (86, 718)
# Right points r1 and r2, (641, 320) (1194, 679)
# Left points l1 and l2, (636, 320) (62, 718)
# Right points r1 and r2, (642, 325) (1188, 677)
# Left points l1 and l2, (639, 325) (54, 686)
#  58%|█████▊    | 145/251 [00:18<00:13,  8.08it/s]
# Right points r1 and r2, (644, 326) (1191, 678)
# Left points l1 and l2, (639, 326) (69, 687)
# Right points r1 and r2, (641, 328) (1187, 677)
# Left points l1 and l2, (639, 328) (53, 700)
#  59%|█████▊    | 147/251 [00:19<00:11,  8.77it/s]
# Right points r1 and r2, (642, 328) (1177, 678)
# Left points l1 and l2, (639, 328) (71, 700)
# Right points r1 and r2, (641, 328) (1192, 678)
# Left points l1 and l2, (635, 328) (69, 700)
#  59%|█████▉    | 149/251 [00:19<00:13,  7.40it/s]
# Right points r1 and r2, (641, 328) (1189, 673)
# Left points l1 and l2, (639, 328) (59, 699)
# Right points r1 and r2, (642, 329) (1189, 678)
# Left points l1 and l2, (638, 329) (83, 701)
#  60%|█████▉    | 150/251 [00:19<00:13,  7.60it/s]
# Right points r1 and r2, (643, 328) (1211, 703)
# Left points l1 and l2, (639, 328) (72, 699)
# Right points r1 and r2, (647, 327) (1194, 705)
# Left points l1 and l2, (635, 327) (71, 686)
#  61%|██████    | 153/251 [00:19<00:12,  7.88it/s]
# Right points r1 and r2, (641, 328) (1212, 715)
# Left points l1 and l2, (639, 328) (70, 686)
# Right points r1 and r2, (658, 327) (1189, 677)
# Left points l1 and l2, (636, 327) (64, 699)
#  61%|██████▏   | 154/251 [00:19<00:12,  7.89it/s]
# Right points r1 and r2, (646, 327) (1240, 707)
# Left points l1 and l2, (636, 327) (85, 710)
# Right points r1 and r2, (647, 325) (1172, 680)
# Left points l1 and l2, (636, 325) (55, 699)
#  63%|██████▎   | 157/251 [00:20<00:12,  7.73it/s]
# Right points r1 and r2, (642, 327) (1200, 679)
# Left points l1 and l2, (639, 327) (91, 685)
# Right points r1 and r2, (642, 327) (1152, 676)
# Left points l1 and l2, (634, 327) (53, 686)
#  63%|██████▎   | 158/251 [00:20<00:11,  8.19it/s]
# Right points r1 and r2, (642, 323) (1189, 676)
# Left points l1 and l2, (638, 323) (73, 698)
# Right points r1 and r2, (643, 323) (1187, 673)
# Left points l1 and l2, (639, 323) (66, 685)
# Right points r1 and r2, (641, 323) (1209, 702)
#  64%|██████▍   | 161/251 [00:20<00:10,  8.54it/s]
# Left points l1 and l2, (639, 323) (82, 699)
# Right points r1 and r2, (643, 324) (1169, 674)
# Left points l1 and l2, (636, 324) (147, 686)
#  65%|██████▍   | 162/251 [00:20<00:10,  8.42it/s]
# Right points r1 and r2, (641, 324) (1180, 676)
# Left points l1 and l2, (636, 324) (112, 711)
# Right points r1 and r2, (641, 324) (1273, 716)
# Left points l1 and l2, (633, 324) (112, 684)
#  66%|██████▌   | 165/251 [00:21<00:09,  8.75it/s]
# Right points r1 and r2, (643, 327) (1276, 717)
# Left points l1 and l2, (635, 327) (161, 686)
# Right points r1 and r2, (641, 329) (1274, 717)
# Left points l1 and l2, (639, 329) (207, 687)
#  66%|██████▌   | 166/251 [00:21<00:09,  8.76it/s]
# Right points r1 and r2, (641, 330) (1198, 678)
# Left points l1 and l2, (638, 330) (205, 686)
# Right points r1 and r2, (641, 331) (1188, 677)
# Left points l1 and l2, (639, 331) (188, 686)
#  67%|██████▋   | 169/251 [00:21<00:09,  8.69it/s]
# Right points r1 and r2, (641, 332) (1200, 702)
# Left points l1 and l2, (638, 332) (191, 699)
# Right points r1 and r2, (644, 333) (1201, 701)
# Left points l1 and l2, (639, 333) (185, 699)
#  68%|██████▊   | 170/251 [00:21<00:09,  8.53it/s]
# Right points r1 and r2, (641, 330) (1202, 702)
# Left points l1 and l2, (639, 330) (182, 699)
#  68%|██████▊   | 171/251 [00:22<00:15,  5.07it/s]
# Right points r1 and r2, (646, 332) (1213, 702)
# Left points l1 and l2, (636, 332) (183, 700)
#  69%|██████▉   | 173/251 [00:22<00:14,  5.21it/s]
# Right points r1 and r2, (642, 331) (1213, 702)
# Left points l1 and l2, (638, 331) (170, 700)
# Right points r1 and r2, (641, 327) (1189, 676)
# Left points l1 and l2, (639, 327) (173, 702)
#  70%|██████▉   | 175/251 [00:22<00:11,  6.69it/s]
# Right points r1 and r2, (641, 324) (1164, 678)
# Left points l1 and l2, (629, 324) (174, 700)
# Right points r1 and r2, (641, 321) (1191, 677)
# Left points l1 and l2, (632, 321) (181, 699)
#  71%|███████   | 177/251 [00:23<00:12,  6.07it/s]
# Right points r1 and r2, (641, 320) (1187, 677)
# Left points l1 and l2, (638, 320) (194, 699)
# Right points r1 and r2, (641, 323) (1180, 710)
# Left points l1 and l2, (637, 323) (189, 700)
#  71%|███████   | 178/251 [00:23<00:19,  3.68it/s]
# Right points r1 and r2, (641, 321) (1207, 700)
# Left points l1 and l2, (635, 321) (194, 699)
#  71%|███████▏  | 179/251 [00:23<00:17,  4.18it/s]
# Right points r1 and r2, (644, 320) (1210, 703)
# Left points l1 and l2, (637, 320) (192, 686)
#  72%|███████▏  | 180/251 [00:24<00:16,  4.26it/s]
# Right points r1 and r2, (641, 320) (1215, 702)
# Left points l1 and l2, (639, 320) (190, 686)
# Right points r1 and r2, (641, 320) (1211, 701)
# Left points l1 and l2, (639, 320) (187, 699)
# Right points r1 and r2, (642, 320) (1187, 677)
# Left points l1 and l2, (639, 320) (180, 700)
#  73%|███████▎  | 183/251 [00:24<00:13,  5.15it/s]
# Right points r1 and r2, (641, 320) (1187, 710)
# Left points l1 and l2, (639, 320) (181, 700)
#  73%|███████▎  | 184/251 [00:24<00:15,  4.44it/s]
# Right points r1 and r2, (641, 320) (1148, 677)
# Left points l1 and l2, (639, 320) (189, 700)
#  74%|███████▍  | 186/251 [00:25<00:12,  5.19it/s]
# Right points r1 and r2, (643, 322) (1188, 678)
# Left points l1 and l2, (638, 322) (193, 686)
# Right points r1 and r2, (646, 320) (1191, 676)
# Left points l1 and l2, (638, 320) (185, 699)
#  75%|███████▍  | 187/251 [00:25<00:11,  5.80it/s]
# Right points r1 and r2, (641, 321) (1228, 703)
# Left points l1 and l2, (638, 321) (180, 700)
#  75%|███████▌  | 189/251 [00:25<00:09,  6.29it/s]
# Right points r1 and r2, (641, 320) (1192, 677)
# Left points l1 and l2, (638, 320) (179, 700)
# Right points r1 and r2, (641, 320) (1154, 677)
# Left points l1 and l2, (638, 320) (182, 699)
#  76%|███████▌  | 190/251 [00:25<00:12,  5.08it/s]
# Right points r1 and r2, (643, 320) (1189, 677)
# Left points l1 and l2, (635, 320) (179, 700)
#  76%|███████▌  | 191/251 [00:26<00:12,  4.73it/s]
# Right points r1 and r2, (643, 320) (1188, 677)
# Left points l1 and l2, (639, 320) (180, 699)
#  76%|███████▋  | 192/251 [00:26<00:14,  4.16it/s]
# Right points r1 and r2, (643, 320) (1185, 677)
# Left points l1 and l2, (637, 320) (194, 686)
#  77%|███████▋  | 194/251 [00:26<00:11,  4.99it/s]
# Right points r1 and r2, (642, 321) (1186, 678)
# Left points l1 and l2, (639, 321) (181, 700)
# Right points r1 and r2, (644, 320) (1248, 709)
# Left points l1 and l2, (639, 320) (188, 699)
#  78%|███████▊  | 195/251 [00:26<00:10,  5.58it/s]
# Right points r1 and r2, (644, 320) (1192, 677)
# Left points l1 and l2, (637, 320) (179, 686)
# Right points r1 and r2, (642, 320) (1189, 676)
# Left points l1 and l2, (638, 320) (199, 699)
# Right points r1 and r2, (642, 321) (1190, 677)
# Left points l1 and l2, (636, 321) (178, 700)
#  79%|███████▉  | 198/251 [00:27<00:07,  7.16it/s]
# Right points r1 and r2, (641, 321) (1176, 677)
# Left points l1 and l2, (639, 321) (178, 686)
# Right points r1 and r2, (641, 320) (1187, 677)
# Left points l1 and l2, (638, 320) (182, 699)
#  80%|████████  | 201/251 [00:27<00:07,  7.08it/s]
# Right points r1 and r2, (641, 322) (1254, 711)
# Left points l1 and l2, (638, 322) (179, 700)
# Right points r1 and r2, (641, 320) (1160, 678)
# Left points l1 and l2, (639, 320) (194, 686)
# Right points r1 and r2, (641, 323) (1136, 677)
# Left points l1 and l2, (639, 323) (197, 700)
#  81%|████████▏ | 204/251 [00:27<00:05,  8.44it/s]
# Right points r1 and r2, (641, 326) (1174, 677)
# Left points l1 and l2, (637, 326) (179, 686)
# Right points r1 and r2, (641, 327) (1185, 677)
# Left points l1 and l2, (638, 327) (180, 699)
#  82%|████████▏ | 206/251 [00:28<00:05,  8.38it/s]
# Right points r1 and r2, (647, 323) (1186, 678)
# Left points l1 and l2, (639, 323) (183, 686)
# Right points r1 and r2, (641, 323) (1257, 718)
# Left points l1 and l2, (637, 323) (182, 700)
#  82%|████████▏ | 207/251 [00:28<00:05,  7.85it/s]
# Right points r1 and r2, (641, 324) (1192, 678)
# Left points l1 and l2, (639, 324) (182, 700)
# Right points r1 and r2, (641, 325) (1194, 678)
# Left points l1 and l2, (639, 325) (194, 700)
#  84%|████████▎ | 210/251 [00:28<00:05,  7.98it/s]
# Right points r1 and r2, (644, 320) (1192, 677)
# Left points l1 and l2, (637, 320) (179, 700)
# Right points r1 and r2, (641, 324) (1254, 718)
# Left points l1 and l2, (639, 324) (193, 700)
#  84%|████████▍ | 211/251 [00:28<00:04,  8.08it/s]
# Right points r1 and r2, (646, 320) (1194, 678)
# Left points l1 and l2, (635, 320) (190, 687)
# Right points r1 and r2, (641, 334) (1256, 717)
# Left points l1 and l2, (639, 334) (185, 685)
# Right points r1 and r2, (643, 329) (1192, 715)
# Left points l1 and l2, (639, 329) (180, 686)
#  86%|████████▌ | 215/251 [00:29<00:05,  6.45it/s]
# Right points r1 and r2, (642, 323) (1256, 717)
# Left points l1 and l2, (638, 323) (191, 686)
# Right points r1 and r2, (641, 333) (1254, 717)
# Left points l1 and l2, (637, 333) (175, 686)
#  86%|████████▋ | 217/251 [00:29<00:04,  7.41it/s]
# Right points r1 and r2, (641, 324) (1182, 678)
# Left points l1 and l2, (638, 324) (182, 687)
# Right points r1 and r2, (643, 320) (1191, 677)
# Left points l1 and l2, (639, 320) (178, 686)
#  87%|████████▋ | 219/251 [00:29<00:04,  7.33it/s]
# Right points r1 and r2, (652, 320) (1186, 678)
# Left points l1 and l2, (639, 320) (180, 687)
# Right points r1 and r2, (641, 320) (1184, 677)
# Left points l1 and l2, (638, 320) (179, 687)
#  88%|████████▊ | 221/251 [00:30<00:04,  7.32it/s]
# Right points r1 and r2, (644, 328) (1191, 713)
# Left points l1 and l2, (637, 328) (188, 685)
# Right points r1 and r2, (644, 320) (1192, 678)
# Left points l1 and l2, (639, 320) (183, 700)
#  89%|████████▉ | 223/251 [00:30<00:03,  7.96it/s]
# Right points r1 and r2, (641, 320) (1274, 718)
# Left points l1 and l2, (636, 320) (179, 684)
# Right points r1 and r2, (641, 320) (1192, 678)
# Left points l1 and l2, (639, 320) (184, 701)
# Right points r1 and r2, (645, 320) (1194, 712)
# Left points l1 and l2, (636, 320) (182, 700)
#  90%|████████▉ | 225/251 [00:30<00:02,  8.67it/s]
# Right points r1 and r2, (642, 320) (1185, 677)
# Left points l1 and l2, (639, 320) (194, 685)
# Right points r1 and r2, (641, 320) (1188, 677)
# Left points l1 and l2, (639, 320) (190, 686)
# Right points r1 and r2, (641, 320) (1192, 711)
# Left points l1 and l2, (635, 320) (181, 686)
#  91%|█████████ | 229/251 [00:30<00:02,  9.78it/s]
# Right points r1 and r2, (642, 321) (1187, 677)
# Left points l1 and l2, (639, 321) (183, 686)
# Right points r1 and r2, (642, 320) (1184, 711)
# Left points l1 and l2, (637, 320) (183, 686)
# Right points r1 and r2, (641, 320) (1152, 677)
# Left points l1 and l2, (636, 320) (192, 686)
#  92%|█████████▏| 231/251 [00:31<00:02,  9.71it/s]
# Right points r1 and r2, (644, 332) (1189, 707)
# Left points l1 and l2, (638, 332) (183, 686)
# Right points r1 and r2, (641, 320) (1186, 677)
# Left points l1 and l2, (637, 320) (180, 686)
# Right points r1 and r2, (641, 327) (1126, 677)
# Left points l1 and l2, (639, 327) (183, 685)
#  94%|█████████▎| 235/251 [00:31<00:01,  9.66it/s]
# Right points r1 and r2, (641, 320) (1187, 678)
# Left points l1 and l2, (637, 320) (189, 686)
# Right points r1 and r2, (641, 320) (1185, 677)
# Left points l1 and l2, (639, 320) (178, 686)
# Right points r1 and r2, (641, 322) (1191, 677)
# Left points l1 and l2, (638, 322) (196, 685)
#  94%|█████████▍| 237/251 [00:31<00:01,  9.92it/s]
# Right points r1 and r2, (641, 320) (1192, 704)
# Left points l1 and l2, (639, 320) (184, 700)
# Right points r1 and r2, (642, 320) (1184, 709)
# Left points l1 and l2, (639, 320) (180, 685)
#  95%|█████████▌| 239/251 [00:31<00:01,  9.54it/s]
# Right points r1 and r2, (641, 320) (1192, 678)
# Left points l1 and l2, (639, 320) (202, 700)
# Right points r1 and r2, (641, 320) (1227, 698)
# Left points l1 and l2, (639, 320) (171, 700)
# Right points r1 and r2, (642, 320) (1191, 677)
# Left points l1 and l2, (639, 320) (179, 699)
#  97%|█████████▋| 244/251 [00:32<00:00, 10.31it/s]
# Right points r1 and r2, (641, 320) (1192, 704)
# Left points l1 and l2, (639, 320) (185, 687)
# Right points r1 and r2, (641, 320) (1125, 677)
# Left points l1 and l2, (638, 320) (176, 685)
# Right points r1 and r2, (641, 320) (1192, 677)
# Left points l1 and l2, (635, 320) (175, 700)
#  98%|█████████▊| 246/251 [00:32<00:00, 10.20it/s]
# Right points r1 and r2, (641, 320) (1192, 677)
# Left points l1 and l2, (638, 320) (177, 685)
# Right points r1 and r2, (643, 320) (1189, 677)
# Left points l1 and l2, (637, 320) (175, 685)
# Right points r1 and r2, (641, 320) (1123, 678)
# Left points l1 and l2, (633, 320) (180, 700)
#  99%|█████████▉| 248/251 [00:32<00:00, 10.30it/s]
# Right points r1 and r2, (642, 320) (1192, 710)
# Left points l1 and l2, (639, 320) (188, 686)
# Right points r1 and r2, (643, 320) (1192, 710)
# Left points l1 and l2, (639, 320) (183, 699)
# Right points r1 and r2, (641, 322) (1187, 678)
# Left points l1 and l2, (636, 322) (192, 701)
# 100%|██████████| 251/251 [00:33<00:00,  7.59it/s]
# Right points r1 and r2, (641, 320) (1191, 676)
# Left points l1 and l2, (639, 320) (190, 685)
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: extra.mp4
#
# CPU times: user 22.2 s, sys: 2.57 s, total: 24.7 s
# Wall time: 35 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="extra.mp4">
# </video>
